# %%
# !pip install autoviml
# !pip install sklearn-genetic

# %% [markdown]
# # Required Libraires

# %%
import pandas as pd
import numpy as np
from collections import defaultdict
from autoviml.Auto_ViML import Auto_ViML
from sklearn.metrics import classification_report, confusion_matrix,accuracy_score
from sklearn.metrics import balanced_accuracy_score,mean_squared_error
from pprint import pprint
import seaborn as sb
import featuretools as ft
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from sklearn import model_selection
import pickle
import scipy
import statistics as stats
## Lasso search
from sklearn.model_selection import GridSearchCV,cross_val_score
from sklearn.linear_model import Lasso
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
import statsmodels.api as sm
import statsmodels.formula.api as smf
import pickle
sb.set_style('darkgrid')

## Gentic search
from genetic_selection import GeneticSelectionCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from catboost import CatBoostClassifier
from sklearn.linear_model import SGDClassifier
### Hyperopt imports
from hyperopt import hp, tpe, fmin, Trials, STATUS_OK

### optuna imports
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)
import os

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import train_test_split,GridSearchCV,cross_val_score,cross_val_predict
from sklearn.metrics import confusion_matrix,precision_score,recall_score,f1_score

import warnings
warnings.filterwarnings(action = 'ignore')
# Out:
# Imported Auto_ViML version: 0.1.684. Call using:
#              m, feats, trainm, testm = Auto_ViML(train, target, test,
#                             sample_submission='',
#                             scoring_parameter='', KMeans_Featurizer=False,
#                             hyper_param='RS',feature_reduction=True,
#                              Boosting_Flag='CatBoost', Binning_Flag=False,
#                             Add_Poly=0, Stacking_Flag=False,Imbalanced_Flag=False,
#                             verbose=1)
#
#
# Imported Auto_NLP version: 0.0.47.. Call using:
#      train_nlp, test_nlp, nlp_pipeline, predictions = Auto_NLP(
#                 nlp_column, train, test, target, score_type='balanced_accuracy',
#                 modeltype='Classification',top_num_features=200, verbose=0,
#                 build_model=True)
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# # Loading data

# %%
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/parkinson-disease-detection/Parkinsson disease.csv

# %%
data = pd.read_csv('/kaggle/input/parkinson-disease-detection/Parkinsson disease.csv')

# %%
data.head()
# Out:
#              name  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0  phon_R01_S01_1       119.99        157.30         75.00            0.01
# 1  phon_R01_S01_2       122.40        148.65        113.82            0.01
# 2  phon_R01_S01_3       116.68        131.11        111.56            0.01
# 3  phon_R01_S01_4       116.68        137.87        111.37            0.01
# 4  phon_R01_S01_5       116.01        141.78        110.66            0.01
#
#    MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  \
# 0              0.00      0.00      0.01        0.01          0.04
# 1              0.00      0.00      0.01        0.01          0.06
# 2              0.00      0.01      0.01        0.02          0.05
# 3              0.00      0.01      0.01        0.02          0.05
# 4              0.00      0.01      0.01        0.02          0.06
#
#    MDVP:Shimmer(dB)  Shimmer:APQ3  Shimmer:APQ5  MDVP:APQ  Shimmer:DDA  NHR  \
# 0              0.43          0.02          0.03      0.03         0.07 0.02
# 1              0.63          0.03          0.05      0.04         0.09 0.02
# 2              0.48          0.03          0.04      0.04         0.08 0.01
# 3              0.52          0.03          0.04      0.04         0.09 0.01
# 4              0.58          0.03          0.05      0.04         0.10 0.02
#
#     HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0 21.03       1  0.41 0.82    -4.81     0.27 2.30 0.28
# 1 19.09       1  0.46 0.82    -4.08     0.34 2.49 0.37
# 2 20.65       1  0.43 0.83    -4.44     0.31 2.34 0.33
# 3 20.64       1  0.43 0.82    -4.12     0.33 2.41 0.37
# 4 19.65       1  0.42 0.82    -3.75     0.23 2.33 0.41

# %% [markdown]
# # Renaming the columns

# %%
data.rename(columns=({'MDVP:Fo(Hz)':'avg_fre', 'MDVP:Fhi(Hz)':'max_fre', 'MDVP:Flo(Hz)':'min_fre', 'MDVP:Jitter(%)':'var_fre1',
       'MDVP:Jitter(Abs)':'var_fre2', 'MDVP:RAP':'var_fre3', 'MDVP:PPQ':'var_fre4', 'Jitter:DDP':'var_fre5',
       'MDVP:Shimmer':'var_amp1', 'MDVP:Shimmer(dB)':'var_amp2', 'Shimmer:APQ3':'var_amp3', 'Shimmer:APQ5':'var_amp4',
       'MDVP:APQ':'var_amp5', 'Shimmer:DDA':'var_amp6'}),inplace=True)
data.head()
# Out:
#              name  avg_fre  max_fre  min_fre  var_fre1  var_fre2  var_fre3  \
# 0  phon_R01_S01_1   119.99   157.30    75.00      0.01      0.00      0.00
# 1  phon_R01_S01_2   122.40   148.65   113.82      0.01      0.00      0.00
# 2  phon_R01_S01_3   116.68   131.11   111.56      0.01      0.00      0.01
# 3  phon_R01_S01_4   116.68   137.87   111.37      0.01      0.00      0.01
# 4  phon_R01_S01_5   116.01   141.78   110.66      0.01      0.00      0.01
#
#    var_fre4  var_fre5  var_amp1  var_amp2  var_amp3  var_amp4  var_amp5  \
# 0      0.01      0.01      0.04      0.43      0.02      0.03      0.03
# 1      0.01      0.01      0.06      0.63      0.03      0.05      0.04
# 2      0.01      0.02      0.05      0.48      0.03      0.04      0.04
# 3      0.01      0.02      0.05      0.52      0.03      0.04      0.04
# 4      0.01      0.02      0.06      0.58      0.03      0.05      0.04
#
#    var_amp6  NHR   HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0      0.07 0.02 21.03       1  0.41 0.82    -4.81     0.27 2.30 0.28
# 1      0.09 0.02 19.09       1  0.46 0.82    -4.08     0.34 2.49 0.37
# 2      0.08 0.01 20.65       1  0.43 0.83    -4.44     0.31 2.34 0.33
# 3      0.09 0.01 20.64       1  0.43 0.82    -4.12     0.33 2.41 0.37
# 4      0.10 0.02 19.65       1  0.42 0.82    -3.75     0.23 2.33 0.41

# %%
# Dropping Name Column
data.drop('name',1,inplace = True)
data
# Out:
#      avg_fre  max_fre  min_fre  var_fre1  var_fre2  var_fre3  var_fre4  \
# 0     119.99   157.30    75.00      0.01      0.00      0.00      0.01
# 1     122.40   148.65   113.82      0.01      0.00      0.00      0.01
# 2     116.68   131.11   111.56      0.01      0.00      0.01      0.01
# 3     116.68   137.87   111.37      0.01      0.00      0.01      0.01
# 4     116.01   141.78   110.66      0.01      0.00      0.01      0.01
# ..       ...      ...      ...       ...       ...       ...       ...
# 190   174.19   230.98    94.26      0.00      0.00      0.00      0.00
# 191   209.52   253.02    89.49      0.01      0.00      0.00      0.00
# 192   174.69   240.00    74.29      0.01      0.00      0.01      0.01
# 193   198.76   396.96    74.90      0.01      0.00      0.00      0.00
# 194   214.29   260.28    77.97      0.01      0.00      0.00      0.00
#
#      var_fre5  var_amp1  var_amp2  var_amp3  var_amp4  var_amp5  var_amp6  \
# 0        0.01      0.04      0.43      0.02      0.03      0.03      0.07
# 1        0.01      0.06      0.63      0.03      0.05      0.04      0.09
# 2        0.02      0.05      0.48      0.03      0.04      0.04      0.08
# 3        0.02      0.05      0.52      0.03      0.04      0.04      0.09
# 4        0.02      0.06      0.58      0.03      0.05      0.04      0.10
# ..        ...       ...       ...       ...       ...       ...       ...
# 190      0.01      0.04      0.41      0.02      0.02      0.03      0.07
# 191      0.01      0.03      0.26      0.02      0.02      0.02      0.05
# 192      0.02      0.02      0.26      0.01      0.01      0.02      0.04
# 193      0.01      0.02      0.24      0.01      0.01      0.02      0.04
# 194      0.01      0.02      0.19      0.01      0.01      0.01      0.03
#
#      NHR   HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0   0.02 21.03       1  0.41 0.82    -4.81     0.27 2.30 0.28
# 1   0.02 19.09       1  0.46 0.82    -4.08     0.34 2.49 0.37
# 2   0.01 20.65       1  0.43 0.83    -4.44     0.31 2.34 0.33
# 3   0.01 20.64       1  0.43 0.82    -4.12     0.33 2.41 0.37
# 4   0.02 19.65       1  0.42 0.82    -3.75     0.23 2.33 0.41
# ..   ...   ...     ...   ...  ...      ...      ...  ...  ...
# 190 0.03 19.52       0  0.45 0.66    -6.54     0.12 2.66 0.13
# 191 0.02 19.15       0  0.43 0.68    -6.20     0.13 2.78 0.17
# 192 0.11 17.88       0  0.41 0.66    -6.79     0.16 2.68 0.13
# 193 0.07 19.02       0  0.45 0.64    -6.74     0.21 2.14 0.12
# 194 0.04 21.21       0  0.46 0.66    -5.72     0.19 2.56 0.15
#
# [195 rows x 23 columns]

# %% [markdown]
# # PreProcessing

# %%
def preprocessing(data,target_ID):
    processed_data = convert_categorical_to_numbers(data)
    processed_data = auto_data_impute(data)
    processed_data = scaling_data(data,target_ID)
    print("Pre-Processing done")
    return processed_data


def convert_categorical_to_numbers(data,unique_val=10):
    """converts categorical object dtypes to numeric encoded format"""
    obj_df = data.select_dtypes(include=[object])
    unique_list = [f for f in obj_df.columns if obj_df[f].unique().shape[0]>=unique_val]
    obj_df_sel = obj_df.drop(columns=unique_list)
    for col in obj_df_sel.columns:
        data[col] = pd.factorize(data[col])[0]
    print("conversion successfull")
    return data

def auto_data_impute(data,get_rid_percent=2):
    for x,y in data.isnull().sum().items():
        percent = y/data.shape[0]
        if percent <= get_rid_percent/100:
            data[x]  = data[x].fillna(data[x].mean())
        else:
            print("removed column : ",x)
            data = data.drop([x],axis=1)
    print("Data imputation successfull")
    return data

def scaling_data(data,target_ID):
    num_df = data.select_dtypes(include = [int,float])
    for i in num_df:
        if i != target_ID:
            data[i] = data[i]/data[i].max()
    print("scaling was successfull")
    return data

# %%
target_ID = 'status'
data = preprocessing(data,target_ID)
# Out:
# conversion successfull
# Data imputation successfull
# scaling was successfull
# Pre-Processing done

# %%
data
# Out:
#      avg_fre  max_fre  min_fre  var_fre1  var_fre2  var_fre3  var_fre4  \
# 0       0.46     0.27     0.31      0.24      0.27      0.17      0.28
# 1       0.47     0.25     0.48      0.29      0.31      0.22      0.36
# 2       0.45     0.22     0.47      0.32      0.35      0.25      0.40
# 3       0.45     0.23     0.47      0.30      0.35      0.23      0.36
# 4       0.45     0.24     0.46      0.39      0.42      0.31      0.46
# ..       ...      ...      ...       ...       ...       ...       ...
# 190     0.67     0.39     0.39      0.14      0.12      0.12      0.13
# 191     0.81     0.43     0.37      0.17      0.12      0.15      0.15
# 192     0.67     0.41     0.31      0.41      0.31      0.29      0.29
# 193     0.76     0.67     0.31      0.22      0.15      0.17      0.20
# 194     0.82     0.44     0.33      0.17      0.12      0.14      0.16
#
#      var_fre5  var_amp1  var_amp2  var_amp3  var_amp4  var_amp5  var_amp6  \
# 0        0.17      0.37      0.33      0.39      0.39      0.22      0.39
# 1        0.22      0.52      0.48      0.55      0.57      0.32      0.56
# 2        0.25      0.44      0.37      0.49      0.49      0.26      0.49
# 3        0.23      0.46      0.40      0.52      0.50      0.27      0.52
# 4        0.31      0.54      0.45      0.62      0.61      0.32      0.62
# ..        ...       ...       ...       ...       ...       ...       ...
# 190      0.12      0.34      0.31      0.41      0.31      0.20      0.41
# 191      0.15      0.23      0.20      0.28      0.21      0.14      0.28
# 192      0.29      0.19      0.20      0.22      0.17      0.12      0.22
# 193      0.17      0.19      0.19      0.22      0.17      0.12      0.22
# 194      0.14      0.16      0.15      0.18      0.15      0.10      0.18
#
#      NHR  HNR  status  RPDE  DFA  spread1  spread2   D2  PPE
# 0   0.07 0.64       1  0.61 0.99     1.98     0.59 0.63 0.54
# 1   0.06 0.58       1  0.67 0.99     1.67     0.74 0.68 0.70
# 2   0.04 0.62       1  0.63 1.00     1.83     0.69 0.64 0.63
# 3   0.04 0.62       1  0.63 0.99     1.69     0.74 0.66 0.70
# 4   0.06 0.59       1  0.61 1.00     1.54     0.52 0.64 0.78
# ..   ...  ...     ...   ...  ...      ...      ...  ...  ...
# 190 0.09 0.59       0  0.65 0.80     2.69     0.27 0.72 0.25
# 191 0.06 0.58       0  0.63 0.83     2.55     0.29 0.76 0.32
# 192 0.34 0.54       0  0.59 0.79     2.79     0.35 0.73 0.25
# 193 0.23 0.58       0  0.66 0.78     2.77     0.46 0.58 0.23
# 194 0.14 0.64       0  0.68 0.81     2.35     0.42 0.70 0.28
#
# [195 rows x 23 columns]

# %% [markdown]
# # Generating Features

# %%
def generate_feat(eid,df,f):
    es = ft.EntitySet(id = eid)
    es.add_dataframe(dataframe_name = eid, dataframe = df, index = 'id')
    es.normalize_dataframe(base_dataframe_name=eid, new_dataframe_name=f, index = f)
    feature_matrix, feature_names = ft.dfs(entityset=es, 
    target_dataframe_name = eid, #,'Mean',Std','Count', 'Percent_True', 'Num_Unique', 'Trend', 'Skew'],
    max_depth = 4, 
    verbose = 1,n_jobs=-1)
    feature_matrix = feature_matrix.reindex(index=df['id'])
    return feature_matrix

def generate_features(data,target_ID):
    split_idx=data.shape[0]
    first_level_feat = list(data.columns)
    first_level_feat = [t for t in first_level_feat if target_ID!=t]
    first_level_feat  =first_level_feat[:]
    source = data.drop(target_ID,axis=1)
    source.reset_index(drop=True,inplace=True)
    target = data[[target_ID]]
    target.reset_index(drop=True,inplace=True)
    fmx = []
    for s in first_level_feat:
        out_ = generate_feat(target_ID,source,s)
        fmx.append(out_)
    feature_matrix = pd.concat(fmx,axis=1)
    original_ft_feat = list(feature_matrix.columns)
    feature_matrix = feature_matrix.loc[:,~feature_matrix.columns.duplicated()]
    target.reset_index(drop=True,inplace=True)
    target = target.reindex(index=source['id'])
    feature_matrix = pd.merge(feature_matrix,target,right_index=True,left_index=True)
    feature_matrix = auto_data_impute(feature_matrix,get_rid_percent=10)
    return feature_matrix

# %%
feature_matrix = generate_features(data,target_ID)
feature_matrix
# Out:
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:00 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 4 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# Built 149 features
# EntitySet scattered to 4 workers in 3 seconds
# Elapsed: 00:01 | Progress: 100%|██████████
# removed column :  avg_fre.SKEW(status.D2)
# removed column :  avg_fre.SKEW(status.DFA)
# removed column :  avg_fre.SKEW(status.HNR)
# removed column :  avg_fre.SKEW(status.NHR)
# removed column :  avg_fre.SKEW(status.PPE)
# removed column :  avg_fre.SKEW(status.RPDE)
# removed column :  avg_fre.SKEW(status.max_fre)
# removed column :  avg_fre.SKEW(status.min_fre)
# removed column :  avg_fre.SKEW(status.spread1)
# removed column :  avg_fre.SKEW(status.spread2)
# removed column :  avg_fre.SKEW(status.var_amp1)
# removed column :  avg_fre.SKEW(status.var_amp2)
# removed column :  avg_fre.SKEW(status.var_amp3)
# removed column :  avg_fre.SKEW(status.var_amp4)
# removed column :  avg_fre.SKEW(status.var_amp5)
# removed column :  avg_fre.SKEW(status.var_amp6)
# removed column :  avg_fre.SKEW(status.var_fre1)
# removed column :  avg_fre.SKEW(status.var_fre2)
# removed column :  avg_fre.SKEW(status.var_fre3)
# removed column :  avg_fre.SKEW(status.var_fre4)
# removed column :  avg_fre.SKEW(status.var_fre5)
# removed column :  avg_fre.STD(status.D2)
# removed column :  avg_fre.STD(status.DFA)
# removed column :  avg_fre.STD(status.HNR)
# removed column :  avg_fre.STD(status.NHR)
# removed column :  avg_fre.STD(status.PPE)
# removed column :  avg_fre.STD(status.RPDE)
# removed column :  avg_fre.STD(status.max_fre)
# removed column :  avg_fre.STD(status.min_fre)
# removed column :  avg_fre.STD(status.spread1)
# removed column :  avg_fre.STD(status.spread2)
# removed column :  avg_fre.STD(status.var_amp1)
# removed column :  avg_fre.STD(status.var_amp2)
# removed column :  avg_fre.STD(status.var_amp3)
# removed column :  avg_fre.STD(status.var_amp4)
# removed column :  avg_fre.STD(status.var_amp5)
# removed column :  avg_fre.STD(status.var_amp6)
# removed column :  avg_fre.STD(status.var_fre1)
# removed column :  avg_fre.STD(status.var_fre2)
# removed column :  avg_fre.STD(status.var_fre3)
# removed column :  avg_fre.STD(status.var_fre4)
# removed column :  avg_fre.STD(status.var_fre5)
# removed column :  max_fre.SKEW(status.D2)
# removed column :  max_fre.SKEW(status.DFA)
# removed column :  max_fre.SKEW(status.HNR)
# removed column :  max_fre.SKEW(status.NHR)
# removed column :  max_fre.SKEW(status.PPE)
# removed column :  max_fre.SKEW(status.RPDE)
# removed column :  max_fre.SKEW(status.avg_fre)
# removed column :  max_fre.SKEW(status.min_fre)
# removed column :  max_fre.SKEW(status.spread1)
# removed column :  max_fre.SKEW(status.spread2)
# removed column :  max_fre.SKEW(status.var_amp1)
# removed column :  max_fre.SKEW(status.var_amp2)
# removed column :  max_fre.SKEW(status.var_amp3)
# removed column :  max_fre.SKEW(status.var_amp4)
# removed column :  max_fre.SKEW(status.var_amp5)
# removed column :  max_fre.SKEW(status.var_amp6)
# removed column :  max_fre.SKEW(status.var_fre1)
# removed column :  max_fre.SKEW(status.var_fre2)
# removed column :  max_fre.SKEW(status.var_fre3)
# removed column :  max_fre.SKEW(status.var_fre4)
# removed column :  max_fre.SKEW(status.var_fre5)
# removed column :  max_fre.STD(status.D2)
# removed column :  max_fre.STD(status.DFA)
# removed column :  max_fre.STD(status.HNR)
# removed column :  max_fre.STD(status.NHR)
# removed column :  max_fre.STD(status.PPE)
# removed column :  max_fre.STD(status.RPDE)
# removed column :  max_fre.STD(status.avg_fre)
# removed column :  max_fre.STD(status.min_fre)
# removed column :  max_fre.STD(status.spread1)
# removed column :  max_fre.STD(status.spread2)
# removed column :  max_fre.STD(status.var_amp1)
# removed column :  max_fre.STD(status.var_amp2)
# removed column :  max_fre.STD(status.var_amp3)
# removed column :  max_fre.STD(status.var_amp4)
# removed column :  max_fre.STD(status.var_amp5)
# removed column :  max_fre.STD(status.var_amp6)
# removed column :  max_fre.STD(status.var_fre1)
# removed column :  max_fre.STD(status.var_fre2)
# removed column :  max_fre.STD(status.var_fre3)
# removed column :  max_fre.STD(status.var_fre4)
# removed column :  max_fre.STD(status.var_fre5)
# removed column :  min_fre.SKEW(status.D2)
# removed column :  min_fre.SKEW(status.DFA)
# removed column :  min_fre.SKEW(status.HNR)
# removed column :  min_fre.SKEW(status.NHR)
# removed column :  min_fre.SKEW(status.PPE)
# removed column :  min_fre.SKEW(status.RPDE)
# removed column :  min_fre.SKEW(status.avg_fre)
# removed column :  min_fre.SKEW(status.max_fre)
# removed column :  min_fre.SKEW(status.spread1)
# removed column :  min_fre.SKEW(status.spread2)
# removed column :  min_fre.SKEW(status.var_amp1)
# removed column :  min_fre.SKEW(status.var_amp2)
# removed column :  min_fre.SKEW(status.var_amp3)
# removed column :  min_fre.SKEW(status.var_amp4)
# removed column :  min_fre.SKEW(status.var_amp5)
# removed column :  min_fre.SKEW(status.var_amp6)
# removed column :  min_fre.SKEW(status.var_fre1)
# removed column :  min_fre.SKEW(status.var_fre2)
# removed column :  min_fre.SKEW(status.var_fre3)
# removed column :  min_fre.SKEW(status.var_fre4)
# removed column :  min_fre.SKEW(status.var_fre5)
# removed column :  min_fre.STD(status.D2)
# removed column :  min_fre.STD(status.DFA)
# removed column :  min_fre.STD(status.HNR)
# removed column :  min_fre.STD(status.NHR)
# removed column :  min_fre.STD(status.PPE)
# removed column :  min_fre.STD(status.RPDE)
# removed column :  min_fre.STD(status.avg_fre)
# removed column :  min_fre.STD(status.max_fre)
# removed column :  min_fre.STD(status.spread1)
# removed column :  min_fre.STD(status.spread2)
# removed column :  min_fre.STD(status.var_amp1)
# removed column :  min_fre.STD(status.var_amp2)
# removed column :  min_fre.STD(status.var_amp3)
# removed column :  min_fre.STD(status.var_amp4)
# removed column :  min_fre.STD(status.var_amp5)
# removed column :  min_fre.STD(status.var_amp6)
# removed column :  min_fre.STD(status.var_fre1)
# removed column :  min_fre.STD(status.var_fre2)
# removed column :  min_fre.STD(status.var_fre3)
# removed column :  min_fre.STD(status.var_fre4)
# removed column :  min_fre.STD(status.var_fre5)
# removed column :  var_fre1.SKEW(status.D2)
# removed column :  var_fre1.SKEW(status.DFA)
# removed column :  var_fre1.SKEW(status.HNR)
# removed column :  var_fre1.SKEW(status.NHR)
# removed column :  var_fre1.SKEW(status.PPE)
# removed column :  var_fre1.SKEW(status.RPDE)
# removed column :  var_fre1.SKEW(status.avg_fre)
# removed column :  var_fre1.SKEW(status.max_fre)
# removed column :  var_fre1.SKEW(status.min_fre)
# removed column :  var_fre1.SKEW(status.spread1)
# removed column :  var_fre1.SKEW(status.spread2)
# removed column :  var_fre1.SKEW(status.var_amp1)
# removed column :  var_fre1.SKEW(status.var_amp2)
# removed column :  var_fre1.SKEW(status.var_amp3)
# removed column :  var_fre1.SKEW(status.var_amp4)
# removed column :  var_fre1.SKEW(status.var_amp5)
# removed column :  var_fre1.SKEW(status.var_amp6)
# removed column :  var_fre1.SKEW(status.var_fre2)
# removed column :  var_fre1.SKEW(status.var_fre3)
# removed column :  var_fre1.SKEW(status.var_fre4)
# removed column :  var_fre1.SKEW(status.var_fre5)
# removed column :  var_fre1.STD(status.D2)
# removed column :  var_fre1.STD(status.DFA)
# removed column :  var_fre1.STD(status.HNR)
# removed column :  var_fre1.STD(status.NHR)
# removed column :  var_fre1.STD(status.PPE)
# removed column :  var_fre1.STD(status.RPDE)
# removed column :  var_fre1.STD(status.avg_fre)
# removed column :  var_fre1.STD(status.max_fre)
# removed column :  var_fre1.STD(status.min_fre)
# removed column :  var_fre1.STD(status.spread1)
# removed column :  var_fre1.STD(status.spread2)
# removed column :  var_fre1.STD(status.var_amp1)
# removed column :  var_fre1.STD(status.var_amp2)
# removed column :  var_fre1.STD(status.var_amp3)
# removed column :  var_fre1.STD(status.var_amp4)
# removed column :  var_fre1.STD(status.var_amp5)
# removed column :  var_fre1.STD(status.var_amp6)
# removed column :  var_fre1.STD(status.var_fre2)
# removed column :  var_fre1.STD(status.var_fre3)
# removed column :  var_fre1.STD(status.var_fre4)
# removed column :  var_fre1.STD(status.var_fre5)
# removed column :  var_fre3.SKEW(status.D2)
# removed column :  var_fre3.SKEW(status.DFA)
# removed column :  var_fre3.SKEW(status.HNR)
# removed column :  var_fre3.SKEW(status.NHR)
# removed column :  var_fre3.SKEW(status.PPE)
# removed column :  var_fre3.SKEW(status.RPDE)
# removed column :  var_fre3.SKEW(status.avg_fre)
# removed column :  var_fre3.SKEW(status.max_fre)
# removed column :  var_fre3.SKEW(status.min_fre)
# removed column :  var_fre3.SKEW(status.spread1)
# removed column :  var_fre3.SKEW(status.spread2)
# removed column :  var_fre3.SKEW(status.var_amp1)
# removed column :  var_fre3.SKEW(status.var_amp2)
# removed column :  var_fre3.SKEW(status.var_amp3)
# removed column :  var_fre3.SKEW(status.var_amp4)
# removed column :  var_fre3.SKEW(status.var_amp5)
# removed column :  var_fre3.SKEW(status.var_amp6)
# removed column :  var_fre3.SKEW(status.var_fre1)
# removed column :  var_fre3.SKEW(status.var_fre2)
# removed column :  var_fre3.SKEW(status.var_fre4)
# removed column :  var_fre3.SKEW(status.var_fre5)
# removed column :  var_fre3.STD(status.D2)
# removed column :  var_fre3.STD(status.DFA)
# removed column :  var_fre3.STD(status.HNR)
# removed column :  var_fre3.STD(status.NHR)
# removed column :  var_fre3.STD(status.PPE)
# removed column :  var_fre3.STD(status.RPDE)
# removed column :  var_fre3.STD(status.avg_fre)
# removed column :  var_fre3.STD(status.max_fre)
# removed column :  var_fre3.STD(status.min_fre)
# removed column :  var_fre3.STD(status.spread1)
# removed column :  var_fre3.STD(status.spread2)
# removed column :  var_fre3.STD(status.var_amp1)
# removed column :  var_fre3.STD(status.var_amp2)
# removed column :  var_fre3.STD(status.var_amp3)
# removed column :  var_fre3.STD(status.var_amp4)
# removed column :  var_fre3.STD(status.var_amp5)
# removed column :  var_fre3.STD(status.var_amp6)
# removed column :  var_fre3.STD(status.var_fre1)
# removed column :  var_fre3.STD(status.var_fre2)
# removed column :  var_fre3.STD(status.var_fre4)
# removed column :  var_fre3.STD(status.var_fre5)
# removed column :  var_fre4.SKEW(status.D2)
# removed column :  var_fre4.SKEW(status.DFA)
# removed column :  var_fre4.SKEW(status.HNR)
# removed column :  var_fre4.SKEW(status.NHR)
# removed column :  var_fre4.SKEW(status.PPE)
# removed column :  var_fre4.SKEW(status.RPDE)
# removed column :  var_fre4.SKEW(status.avg_fre)
# removed column :  var_fre4.SKEW(status.max_fre)
# removed column :  var_fre4.SKEW(status.min_fre)
# removed column :  var_fre4.SKEW(status.spread1)
# removed column :  var_fre4.SKEW(status.spread2)
# removed column :  var_fre4.SKEW(status.var_amp1)
# removed column :  var_fre4.SKEW(status.var_amp2)
# removed column :  var_fre4.SKEW(status.var_amp3)
# removed column :  var_fre4.SKEW(status.var_amp4)
# removed column :  var_fre4.SKEW(status.var_amp5)
# removed column :  var_fre4.SKEW(status.var_amp6)
# removed column :  var_fre4.SKEW(status.var_fre1)
# removed column :  var_fre4.SKEW(status.var_fre2)
# removed column :  var_fre4.SKEW(status.var_fre3)
# removed column :  var_fre4.SKEW(status.var_fre5)
# removed column :  var_fre4.STD(status.D2)
# removed column :  var_fre4.STD(status.DFA)
# removed column :  var_fre4.STD(status.HNR)
# removed column :  var_fre4.STD(status.NHR)
# removed column :  var_fre4.STD(status.PPE)
# removed column :  var_fre4.STD(status.RPDE)
# removed column :  var_fre4.STD(status.avg_fre)
# removed column :  var_fre4.STD(status.max_fre)
# removed column :  var_fre4.STD(status.min_fre)
# removed column :  var_fre4.STD(status.spread1)
# removed column :  var_fre4.STD(status.spread2)
# removed column :  var_fre4.STD(status.var_amp1)
# removed column :  var_fre4.STD(status.var_amp2)
# removed column :  var_fre4.STD(status.var_amp3)
# removed column :  var_fre4.STD(status.var_amp4)
# removed column :  var_fre4.STD(status.var_amp5)
# removed column :  var_fre4.STD(status.var_amp6)
# removed column :  var_fre4.STD(status.var_fre1)
# removed column :  var_fre4.STD(status.var_fre2)
# removed column :  var_fre4.STD(status.var_fre3)
# removed column :  var_fre4.STD(status.var_fre5)
# removed column :  var_fre5.SKEW(status.D2)
# removed column :  var_fre5.SKEW(status.DFA)
# removed column :  var_fre5.SKEW(status.HNR)
# removed column :  var_fre5.SKEW(status.NHR)
# removed column :  var_fre5.SKEW(status.PPE)
# removed column :  var_fre5.SKEW(status.RPDE)
# removed column :  var_fre5.SKEW(status.avg_fre)
# removed column :  var_fre5.SKEW(status.max_fre)
# removed column :  var_fre5.SKEW(status.min_fre)
# removed column :  var_fre5.SKEW(status.spread1)
# removed column :  var_fre5.SKEW(status.spread2)
# removed column :  var_fre5.SKEW(status.var_amp1)
# removed column :  var_fre5.SKEW(status.var_amp2)
# removed column :  var_fre5.SKEW(status.var_amp3)
# removed column :  var_fre5.SKEW(status.var_amp4)
# removed column :  var_fre5.SKEW(status.var_amp5)
# removed column :  var_fre5.SKEW(status.var_amp6)
# removed column :  var_fre5.SKEW(status.var_fre1)
# removed column :  var_fre5.SKEW(status.var_fre2)
# removed column :  var_fre5.SKEW(status.var_fre3)
# removed column :  var_fre5.SKEW(status.var_fre4)
# removed column :  var_fre5.STD(status.D2)
# removed column :  var_fre5.STD(status.DFA)
# removed column :  var_fre5.STD(status.HNR)
# removed column :  var_fre5.STD(status.NHR)
# removed column :  var_fre5.STD(status.PPE)
# removed column :  var_fre5.STD(status.RPDE)
# removed column :  var_fre5.STD(status.avg_fre)
# removed column :  var_fre5.STD(status.max_fre)
# removed column :  var_fre5.STD(status.min_fre)
# removed column :  var_fre5.STD(status.spread1)
# removed column :  var_fre5.STD(status.spread2)
# removed column :  var_fre5.STD(status.var_amp1)
# removed column :  var_fre5.STD(status.var_amp2)
# removed column :  var_fre5.STD(status.var_amp3)
# removed column :  var_fre5.STD(status.var_amp4)
# removed column :  var_fre5.STD(status.var_amp5)
# removed column :  var_fre5.STD(status.var_amp6)
# removed column :  var_fre5.STD(status.var_fre1)
# removed column :  var_fre5.STD(status.var_fre2)
# removed column :  var_fre5.STD(status.var_fre3)
# removed column :  var_fre5.STD(status.var_fre4)
# removed column :  var_amp1.SKEW(status.D2)
# removed column :  var_amp1.SKEW(status.DFA)
# removed column :  var_amp1.SKEW(status.HNR)
# removed column :  var_amp1.SKEW(status.NHR)
# removed column :  var_amp1.SKEW(status.PPE)
# removed column :  var_amp1.SKEW(status.RPDE)
# removed column :  var_amp1.SKEW(status.avg_fre)
# removed column :  var_amp1.SKEW(status.max_fre)
# removed column :  var_amp1.SKEW(status.min_fre)
# removed column :  var_amp1.SKEW(status.spread1)
# removed column :  var_amp1.SKEW(status.spread2)
# removed column :  var_amp1.SKEW(status.var_amp2)
# removed column :  var_amp1.SKEW(status.var_amp3)
# removed column :  var_amp1.SKEW(status.var_amp4)
# removed column :  var_amp1.SKEW(status.var_amp5)
# removed column :  var_amp1.SKEW(status.var_amp6)
# removed column :  var_amp1.SKEW(status.var_fre1)
# removed column :  var_amp1.SKEW(status.var_fre2)
# removed column :  var_amp1.SKEW(status.var_fre3)
# removed column :  var_amp1.SKEW(status.var_fre4)
# removed column :  var_amp1.SKEW(status.var_fre5)
# removed column :  var_amp1.STD(status.D2)
# removed column :  var_amp1.STD(status.DFA)
# removed column :  var_amp1.STD(status.HNR)
# removed column :  var_amp1.STD(status.NHR)
# removed column :  var_amp1.STD(status.PPE)
# removed column :  var_amp1.STD(status.RPDE)
# removed column :  var_amp1.STD(status.avg_fre)
# removed column :  var_amp1.STD(status.max_fre)
# removed column :  var_amp1.STD(status.min_fre)
# removed column :  var_amp1.STD(status.spread1)
# removed column :  var_amp1.STD(status.spread2)
# removed column :  var_amp1.STD(status.var_amp2)
# removed column :  var_amp1.STD(status.var_amp3)
# removed column :  var_amp1.STD(status.var_amp4)
# removed column :  var_amp1.STD(status.var_amp5)
# removed column :  var_amp1.STD(status.var_amp6)
# removed column :  var_amp1.STD(status.var_fre1)
# removed column :  var_amp1.STD(status.var_fre2)
# removed column :  var_amp1.STD(status.var_fre3)
# removed column :  var_amp1.STD(status.var_fre4)
# removed column :  var_amp1.STD(status.var_fre5)
# removed column :  var_amp2.SKEW(status.D2)
# removed column :  var_amp2.SKEW(status.DFA)
# removed column :  var_amp2.SKEW(status.HNR)
# removed column :  var_amp2.SKEW(status.NHR)
# removed column :  var_amp2.SKEW(status.PPE)
# removed column :  var_amp2.SKEW(status.RPDE)
# removed column :  var_amp2.SKEW(status.avg_fre)
# removed column :  var_amp2.SKEW(status.max_fre)
# removed column :  var_amp2.SKEW(status.min_fre)
# removed column :  var_amp2.SKEW(status.spread1)
# removed column :  var_amp2.SKEW(status.spread2)
# removed column :  var_amp2.SKEW(status.var_amp1)
# removed column :  var_amp2.SKEW(status.var_amp3)
# removed column :  var_amp2.SKEW(status.var_amp4)
# removed column :  var_amp2.SKEW(status.var_amp5)
# removed column :  var_amp2.SKEW(status.var_amp6)
# removed column :  var_amp2.SKEW(status.var_fre1)
# removed column :  var_amp2.SKEW(status.var_fre2)
# removed column :  var_amp2.SKEW(status.var_fre3)
# removed column :  var_amp2.SKEW(status.var_fre4)
# removed column :  var_amp2.SKEW(status.var_fre5)
# removed column :  var_amp2.STD(status.D2)
# removed column :  var_amp2.STD(status.DFA)
# removed column :  var_amp2.STD(status.HNR)
# removed column :  var_amp2.STD(status.NHR)
# removed column :  var_amp2.STD(status.PPE)
# removed column :  var_amp2.STD(status.RPDE)
# removed column :  var_amp2.STD(status.avg_fre)
# removed column :  var_amp2.STD(status.max_fre)
# removed column :  var_amp2.STD(status.min_fre)
# removed column :  var_amp2.STD(status.spread1)
# removed column :  var_amp2.STD(status.spread2)
# removed column :  var_amp2.STD(status.var_amp1)
# removed column :  var_amp2.STD(status.var_amp3)
# removed column :  var_amp2.STD(status.var_amp4)
# removed column :  var_amp2.STD(status.var_amp5)
# removed column :  var_amp2.STD(status.var_amp6)
# removed column :  var_amp2.STD(status.var_fre1)
# removed column :  var_amp2.STD(status.var_fre2)
# removed column :  var_amp2.STD(status.var_fre3)
# removed column :  var_amp2.STD(status.var_fre4)
# removed column :  var_amp2.STD(status.var_fre5)
# removed column :  var_amp3.SKEW(status.D2)
# removed column :  var_amp3.SKEW(status.DFA)
# removed column :  var_amp3.SKEW(status.HNR)
# removed column :  var_amp3.SKEW(status.NHR)
# removed column :  var_amp3.SKEW(status.PPE)
# removed column :  var_amp3.SKEW(status.RPDE)
# removed column :  var_amp3.SKEW(status.avg_fre)
# removed column :  var_amp3.SKEW(status.max_fre)
# removed column :  var_amp3.SKEW(status.min_fre)
# removed column :  var_amp3.SKEW(status.spread1)
# removed column :  var_amp3.SKEW(status.spread2)
# removed column :  var_amp3.SKEW(status.var_amp1)
# removed column :  var_amp3.SKEW(status.var_amp2)
# removed column :  var_amp3.SKEW(status.var_amp4)
# removed column :  var_amp3.SKEW(status.var_amp5)
# removed column :  var_amp3.SKEW(status.var_amp6)
# removed column :  var_amp3.SKEW(status.var_fre1)
# removed column :  var_amp3.SKEW(status.var_fre2)
# removed column :  var_amp3.SKEW(status.var_fre3)
# removed column :  var_amp3.SKEW(status.var_fre4)
# removed column :  var_amp3.SKEW(status.var_fre5)
# removed column :  var_amp3.STD(status.D2)
# removed column :  var_amp3.STD(status.DFA)
# removed column :  var_amp3.STD(status.HNR)
# removed column :  var_amp3.STD(status.NHR)
# removed column :  var_amp3.STD(status.PPE)
# removed column :  var_amp3.STD(status.RPDE)
# removed column :  var_amp3.STD(status.avg_fre)
# removed column :  var_amp3.STD(status.max_fre)
# removed column :  var_amp3.STD(status.min_fre)
# removed column :  var_amp3.STD(status.spread1)
# removed column :  var_amp3.STD(status.spread2)
# removed column :  var_amp3.STD(status.var_amp1)
# removed column :  var_amp3.STD(status.var_amp2)
# removed column :  var_amp3.STD(status.var_amp4)
# removed column :  var_amp3.STD(status.var_amp5)
# removed column :  var_amp3.STD(status.var_amp6)
# removed column :  var_amp3.STD(status.var_fre1)
# removed column :  var_amp3.STD(status.var_fre2)
# removed column :  var_amp3.STD(status.var_fre3)
# removed column :  var_amp3.STD(status.var_fre4)
# removed column :  var_amp3.STD(status.var_fre5)
# removed column :  var_amp4.SKEW(status.D2)
# removed column :  var_amp4.SKEW(status.DFA)
# removed column :  var_amp4.SKEW(status.HNR)
# removed column :  var_amp4.SKEW(status.NHR)
# removed column :  var_amp4.SKEW(status.PPE)
# removed column :  var_amp4.SKEW(status.RPDE)
# removed column :  var_amp4.SKEW(status.avg_fre)
# removed column :  var_amp4.SKEW(status.max_fre)
# removed column :  var_amp4.SKEW(status.min_fre)
# removed column :  var_amp4.SKEW(status.spread1)
# removed column :  var_amp4.SKEW(status.spread2)
# removed column :  var_amp4.SKEW(status.var_amp1)
# removed column :  var_amp4.SKEW(status.var_amp2)
# removed column :  var_amp4.SKEW(status.var_amp3)
# removed column :  var_amp4.SKEW(status.var_amp5)
# removed column :  var_amp4.SKEW(status.var_amp6)
# removed column :  var_amp4.SKEW(status.var_fre1)
# removed column :  var_amp4.SKEW(status.var_fre2)
# removed column :  var_amp4.SKEW(status.var_fre3)
# removed column :  var_amp4.SKEW(status.var_fre4)
# removed column :  var_amp4.SKEW(status.var_fre5)
# removed column :  var_amp4.STD(status.D2)
# removed column :  var_amp4.STD(status.DFA)
# removed column :  var_amp4.STD(status.HNR)
# removed column :  var_amp4.STD(status.NHR)
# removed column :  var_amp4.STD(status.PPE)
# removed column :  var_amp4.STD(status.RPDE)
# removed column :  var_amp4.STD(status.avg_fre)
# removed column :  var_amp4.STD(status.max_fre)
# removed column :  var_amp4.STD(status.min_fre)
# removed column :  var_amp4.STD(status.spread1)
# removed column :  var_amp4.STD(status.spread2)
# removed column :  var_amp4.STD(status.var_amp1)
# removed column :  var_amp4.STD(status.var_amp2)
# removed column :  var_amp4.STD(status.var_amp3)
# removed column :  var_amp4.STD(status.var_amp5)
# removed column :  var_amp4.STD(status.var_amp6)
# removed column :  var_amp4.STD(status.var_fre1)
# removed column :  var_amp4.STD(status.var_fre2)
# removed column :  var_amp4.STD(status.var_fre3)
# removed column :  var_amp4.STD(status.var_fre4)
# removed column :  var_amp4.STD(status.var_fre5)
# removed column :  var_amp5.SKEW(status.D2)
# removed column :  var_amp5.SKEW(status.DFA)
# removed column :  var_amp5.SKEW(status.HNR)
# removed column :  var_amp5.SKEW(status.NHR)
# removed column :  var_amp5.SKEW(status.PPE)
# removed column :  var_amp5.SKEW(status.RPDE)
# removed column :  var_amp5.SKEW(status.avg_fre)
# removed column :  var_amp5.SKEW(status.max_fre)
# removed column :  var_amp5.SKEW(status.min_fre)
# removed column :  var_amp5.SKEW(status.spread1)
# removed column :  var_amp5.SKEW(status.spread2)
# removed column :  var_amp5.SKEW(status.var_amp1)
# removed column :  var_amp5.SKEW(status.var_amp2)
# removed column :  var_amp5.SKEW(status.var_amp3)
# removed column :  var_amp5.SKEW(status.var_amp4)
# removed column :  var_amp5.SKEW(status.var_amp6)
# removed column :  var_amp5.SKEW(status.var_fre1)
# removed column :  var_amp5.SKEW(status.var_fre2)
# removed column :  var_amp5.SKEW(status.var_fre3)
# removed column :  var_amp5.SKEW(status.var_fre4)
# removed column :  var_amp5.SKEW(status.var_fre5)
# removed column :  var_amp5.STD(status.D2)
# removed column :  var_amp5.STD(status.DFA)
# removed column :  var_amp5.STD(status.HNR)
# removed column :  var_amp5.STD(status.NHR)
# removed column :  var_amp5.STD(status.PPE)
# removed column :  var_amp5.STD(status.RPDE)
# removed column :  var_amp5.STD(status.avg_fre)
# removed column :  var_amp5.STD(status.max_fre)
# removed column :  var_amp5.STD(status.min_fre)
# removed column :  var_amp5.STD(status.spread1)
# removed column :  var_amp5.STD(status.spread2)
# removed column :  var_amp5.STD(status.var_amp1)
# removed column :  var_amp5.STD(status.var_amp2)
# removed column :  var_amp5.STD(status.var_amp3)
# removed column :  var_amp5.STD(status.var_amp4)
# removed column :  var_amp5.STD(status.var_amp6)
# removed column :  var_amp5.STD(status.var_fre1)
# removed column :  var_amp5.STD(status.var_fre2)
# removed column :  var_amp5.STD(status.var_fre3)
# removed column :  var_amp5.STD(status.var_fre4)
# removed column :  var_amp5.STD(status.var_fre5)
# removed column :  var_amp6.SKEW(status.D2)
# removed column :  var_amp6.SKEW(status.DFA)
# removed column :  var_amp6.SKEW(status.HNR)
# removed column :  var_amp6.SKEW(status.NHR)
# removed column :  var_amp6.SKEW(status.PPE)
# removed column :  var_amp6.SKEW(status.RPDE)
# removed column :  var_amp6.SKEW(status.avg_fre)
# removed column :  var_amp6.SKEW(status.max_fre)
# removed column :  var_amp6.SKEW(status.min_fre)
# removed column :  var_amp6.SKEW(status.spread1)
# removed column :  var_amp6.SKEW(status.spread2)
# removed column :  var_amp6.SKEW(status.var_amp1)
# removed column :  var_amp6.SKEW(status.var_amp2)
# removed column :  var_amp6.SKEW(status.var_amp3)
# removed column :  var_amp6.SKEW(status.var_amp4)
# removed column :  var_amp6.SKEW(status.var_amp5)
# removed column :  var_amp6.SKEW(status.var_fre1)
# removed column :  var_amp6.SKEW(status.var_fre2)
# removed column :  var_amp6.SKEW(status.var_fre3)
# removed column :  var_amp6.SKEW(status.var_fre4)
# removed column :  var_amp6.SKEW(status.var_fre5)
# removed column :  var_amp6.STD(status.D2)
# removed column :  var_amp6.STD(status.DFA)
# removed column :  var_amp6.STD(status.HNR)
# removed column :  var_amp6.STD(status.NHR)
# removed column :  var_amp6.STD(status.PPE)
# removed column :  var_amp6.STD(status.RPDE)
# removed column :  var_amp6.STD(status.avg_fre)
# removed column :  var_amp6.STD(status.max_fre)
# removed column :  var_amp6.STD(status.min_fre)
# removed column :  var_amp6.STD(status.spread1)
# removed column :  var_amp6.STD(status.spread2)
# removed column :  var_amp6.STD(status.var_amp1)
# removed column :  var_amp6.STD(status.var_amp2)
# removed column :  var_amp6.STD(status.var_amp3)
# removed column :  var_amp6.STD(status.var_amp4)
# removed column :  var_amp6.STD(status.var_amp5)
# removed column :  var_amp6.STD(status.var_fre1)
# removed column :  var_amp6.STD(status.var_fre2)
# removed column :  var_amp6.STD(status.var_fre3)
# removed column :  var_amp6.STD(status.var_fre4)
# removed column :  var_amp6.STD(status.var_fre5)
# removed column :  NHR.SKEW(status.D2)
# removed column :  NHR.SKEW(status.DFA)
# removed column :  NHR.SKEW(status.HNR)
# removed column :  NHR.SKEW(status.PPE)
# removed column :  NHR.SKEW(status.RPDE)
# removed column :  NHR.SKEW(status.avg_fre)
# removed column :  NHR.SKEW(status.max_fre)
# removed column :  NHR.SKEW(status.min_fre)
# removed column :  NHR.SKEW(status.spread1)
# removed column :  NHR.SKEW(status.spread2)
# removed column :  NHR.SKEW(status.var_amp1)
# removed column :  NHR.SKEW(status.var_amp2)
# removed column :  NHR.SKEW(status.var_amp3)
# removed column :  NHR.SKEW(status.var_amp4)
# removed column :  NHR.SKEW(status.var_amp5)
# removed column :  NHR.SKEW(status.var_amp6)
# removed column :  NHR.SKEW(status.var_fre1)
# removed column :  NHR.SKEW(status.var_fre2)
# removed column :  NHR.SKEW(status.var_fre3)
# removed column :  NHR.SKEW(status.var_fre4)
# removed column :  NHR.SKEW(status.var_fre5)
# removed column :  NHR.STD(status.D2)
# removed column :  NHR.STD(status.DFA)
# removed column :  NHR.STD(status.HNR)
# removed column :  NHR.STD(status.PPE)
# removed column :  NHR.STD(status.RPDE)
# removed column :  NHR.STD(status.avg_fre)
# removed column :  NHR.STD(status.max_fre)
# removed column :  NHR.STD(status.min_fre)
# removed column :  NHR.STD(status.spread1)
# removed column :  NHR.STD(status.spread2)
# removed column :  NHR.STD(status.var_amp1)
# removed column :  NHR.STD(status.var_amp2)
# removed column :  NHR.STD(status.var_amp3)
# removed column :  NHR.STD(status.var_amp4)
# removed column :  NHR.STD(status.var_amp5)
# removed column :  NHR.STD(status.var_amp6)
# removed column :  NHR.STD(status.var_fre1)
# removed column :  NHR.STD(status.var_fre2)
# removed column :  NHR.STD(status.var_fre3)
# removed column :  NHR.STD(status.var_fre4)
# removed column :  NHR.STD(status.var_fre5)
# removed column :  HNR.SKEW(status.D2)
# removed column :  HNR.SKEW(status.DFA)
# removed column :  HNR.SKEW(status.NHR)
# removed column :  HNR.SKEW(status.PPE)
# removed column :  HNR.SKEW(status.RPDE)
# removed column :  HNR.SKEW(status.avg_fre)
# removed column :  HNR.SKEW(status.max_fre)
# removed column :  HNR.SKEW(status.min_fre)
# removed column :  HNR.SKEW(status.spread1)
# removed column :  HNR.SKEW(status.spread2)
# removed column :  HNR.SKEW(status.var_amp1)
# removed column :  HNR.SKEW(status.var_amp2)
# removed column :  HNR.SKEW(status.var_amp3)
# removed column :  HNR.SKEW(status.var_amp4)
# removed column :  HNR.SKEW(status.var_amp5)
# removed column :  HNR.SKEW(status.var_amp6)
# removed column :  HNR.SKEW(status.var_fre1)
# removed column :  HNR.SKEW(status.var_fre2)
# removed column :  HNR.SKEW(status.var_fre3)
# removed column :  HNR.SKEW(status.var_fre4)
# removed column :  HNR.SKEW(status.var_fre5)
# removed column :  HNR.STD(status.D2)
# removed column :  HNR.STD(status.DFA)
# removed column :  HNR.STD(status.NHR)
# removed column :  HNR.STD(status.PPE)
# removed column :  HNR.STD(status.RPDE)
# removed column :  HNR.STD(status.avg_fre)
# removed column :  HNR.STD(status.max_fre)
# removed column :  HNR.STD(status.min_fre)
# removed column :  HNR.STD(status.spread1)
# removed column :  HNR.STD(status.spread2)
# removed column :  HNR.STD(status.var_amp1)
# removed column :  HNR.STD(status.var_amp2)
# removed column :  HNR.STD(status.var_amp3)
# removed column :  HNR.STD(status.var_amp4)
# removed column :  HNR.STD(status.var_amp5)
# removed column :  HNR.STD(status.var_amp6)
# removed column :  HNR.STD(status.var_fre1)
# removed column :  HNR.STD(status.var_fre2)
# removed column :  HNR.STD(status.var_fre3)
# removed column :  HNR.STD(status.var_fre4)
# removed column :  HNR.STD(status.var_fre5)
# removed column :  RPDE.SKEW(status.D2)
# removed column :  RPDE.SKEW(status.DFA)
# removed column :  RPDE.SKEW(status.HNR)
# removed column :  RPDE.SKEW(status.NHR)
# removed column :  RPDE.SKEW(status.PPE)
# removed column :  RPDE.SKEW(status.avg_fre)
# removed column :  RPDE.SKEW(status.max_fre)
# removed column :  RPDE.SKEW(status.min_fre)
# removed column :  RPDE.SKEW(status.spread1)
# removed column :  RPDE.SKEW(status.spread2)
# removed column :  RPDE.SKEW(status.var_amp1)
# removed column :  RPDE.SKEW(status.var_amp2)
# removed column :  RPDE.SKEW(status.var_amp3)
# removed column :  RPDE.SKEW(status.var_amp4)
# removed column :  RPDE.SKEW(status.var_amp5)
# removed column :  RPDE.SKEW(status.var_amp6)
# removed column :  RPDE.SKEW(status.var_fre1)
# removed column :  RPDE.SKEW(status.var_fre2)
# removed column :  RPDE.SKEW(status.var_fre3)
# removed column :  RPDE.SKEW(status.var_fre4)
# removed column :  RPDE.SKEW(status.var_fre5)
# removed column :  RPDE.STD(status.D2)
# removed column :  RPDE.STD(status.DFA)
# removed column :  RPDE.STD(status.HNR)
# removed column :  RPDE.STD(status.NHR)
# removed column :  RPDE.STD(status.PPE)
# removed column :  RPDE.STD(status.avg_fre)
# removed column :  RPDE.STD(status.max_fre)
# removed column :  RPDE.STD(status.min_fre)
# removed column :  RPDE.STD(status.spread1)
# removed column :  RPDE.STD(status.spread2)
# removed column :  RPDE.STD(status.var_amp1)
# removed column :  RPDE.STD(status.var_amp2)
# removed column :  RPDE.STD(status.var_amp3)
# removed column :  RPDE.STD(status.var_amp4)
# removed column :  RPDE.STD(status.var_amp5)
# removed column :  RPDE.STD(status.var_amp6)
# removed column :  RPDE.STD(status.var_fre1)
# removed column :  RPDE.STD(status.var_fre2)
# removed column :  RPDE.STD(status.var_fre3)
# removed column :  RPDE.STD(status.var_fre4)
# removed column :  RPDE.STD(status.var_fre5)
# removed column :  DFA.SKEW(status.D2)
# removed column :  DFA.SKEW(status.HNR)
# removed column :  DFA.SKEW(status.NHR)
# removed column :  DFA.SKEW(status.PPE)
# removed column :  DFA.SKEW(status.RPDE)
# removed column :  DFA.SKEW(status.avg_fre)
# removed column :  DFA.SKEW(status.max_fre)
# removed column :  DFA.SKEW(status.min_fre)
# removed column :  DFA.SKEW(status.spread1)
# removed column :  DFA.SKEW(status.spread2)
# removed column :  DFA.SKEW(status.var_amp1)
# removed column :  DFA.SKEW(status.var_amp2)
# removed column :  DFA.SKEW(status.var_amp3)
# removed column :  DFA.SKEW(status.var_amp4)
# removed column :  DFA.SKEW(status.var_amp5)
# removed column :  DFA.SKEW(status.var_amp6)
# removed column :  DFA.SKEW(status.var_fre1)
# removed column :  DFA.SKEW(status.var_fre2)
# removed column :  DFA.SKEW(status.var_fre3)
# removed column :  DFA.SKEW(status.var_fre4)
# removed column :  DFA.SKEW(status.var_fre5)
# removed column :  DFA.STD(status.D2)
# removed column :  DFA.STD(status.HNR)
# removed column :  DFA.STD(status.NHR)
# removed column :  DFA.STD(status.PPE)
# removed column :  DFA.STD(status.RPDE)
# removed column :  DFA.STD(status.avg_fre)
# removed column :  DFA.STD(status.max_fre)
# removed column :  DFA.STD(status.min_fre)
# removed column :  DFA.STD(status.spread1)
# removed column :  DFA.STD(status.spread2)
# removed column :  DFA.STD(status.var_amp1)
# removed column :  DFA.STD(status.var_amp2)
# removed column :  DFA.STD(status.var_amp3)
# removed column :  DFA.STD(status.var_amp4)
# removed column :  DFA.STD(status.var_amp5)
# removed column :  DFA.STD(status.var_amp6)
# removed column :  DFA.STD(status.var_fre1)
# removed column :  DFA.STD(status.var_fre2)
# removed column :  DFA.STD(status.var_fre3)
# removed column :  DFA.STD(status.var_fre4)
# removed column :  DFA.STD(status.var_fre5)
# removed column :  spread1.SKEW(status.D2)
# removed column :  spread1.SKEW(status.DFA)
# removed column :  spread1.SKEW(status.HNR)
# removed column :  spread1.SKEW(status.NHR)
# removed column :  spread1.SKEW(status.PPE)
# removed column :  spread1.SKEW(status.RPDE)
# removed column :  spread1.SKEW(status.avg_fre)
# removed column :  spread1.SKEW(status.max_fre)
# removed column :  spread1.SKEW(status.min_fre)
# removed column :  spread1.SKEW(status.spread2)
# removed column :  spread1.SKEW(status.var_amp1)
# removed column :  spread1.SKEW(status.var_amp2)
# removed column :  spread1.SKEW(status.var_amp3)
# removed column :  spread1.SKEW(status.var_amp4)
# removed column :  spread1.SKEW(status.var_amp5)
# removed column :  spread1.SKEW(status.var_amp6)
# removed column :  spread1.SKEW(status.var_fre1)
# removed column :  spread1.SKEW(status.var_fre2)
# removed column :  spread1.SKEW(status.var_fre3)
# removed column :  spread1.SKEW(status.var_fre4)
# removed column :  spread1.SKEW(status.var_fre5)
# removed column :  spread1.STD(status.D2)
# removed column :  spread1.STD(status.DFA)
# removed column :  spread1.STD(status.HNR)
# removed column :  spread1.STD(status.NHR)
# removed column :  spread1.STD(status.PPE)
# removed column :  spread1.STD(status.RPDE)
# removed column :  spread1.STD(status.avg_fre)
# removed column :  spread1.STD(status.max_fre)
# removed column :  spread1.STD(status.min_fre)
# removed column :  spread1.STD(status.spread2)
# removed column :  spread1.STD(status.var_amp1)
# removed column :  spread1.STD(status.var_amp2)
# removed column :  spread1.STD(status.var_amp3)
# removed column :  spread1.STD(status.var_amp4)
# removed column :  spread1.STD(status.var_amp5)
# removed column :  spread1.STD(status.var_amp6)
# removed column :  spread1.STD(status.var_fre1)
# removed column :  spread1.STD(status.var_fre2)
# removed column :  spread1.STD(status.var_fre3)
# removed column :  spread1.STD(status.var_fre4)
# removed column :  spread1.STD(status.var_fre5)
# removed column :  spread2.SKEW(status.D2)
# removed column :  spread2.SKEW(status.DFA)
# removed column :  spread2.SKEW(status.HNR)
# removed column :  spread2.SKEW(status.NHR)
# removed column :  spread2.SKEW(status.PPE)
# removed column :  spread2.SKEW(status.RPDE)
# removed column :  spread2.SKEW(status.avg_fre)
# removed column :  spread2.SKEW(status.max_fre)
# removed column :  spread2.SKEW(status.min_fre)
# removed column :  spread2.SKEW(status.spread1)
# removed column :  spread2.SKEW(status.var_amp1)
# removed column :  spread2.SKEW(status.var_amp2)
# removed column :  spread2.SKEW(status.var_amp3)
# removed column :  spread2.SKEW(status.var_amp4)
# removed column :  spread2.SKEW(status.var_amp5)
# removed column :  spread2.SKEW(status.var_amp6)
# removed column :  spread2.SKEW(status.var_fre1)
# removed column :  spread2.SKEW(status.var_fre2)
# removed column :  spread2.SKEW(status.var_fre3)
# removed column :  spread2.SKEW(status.var_fre4)
# removed column :  spread2.SKEW(status.var_fre5)
# removed column :  spread2.STD(status.D2)
# removed column :  spread2.STD(status.DFA)
# removed column :  spread2.STD(status.HNR)
# removed column :  spread2.STD(status.NHR)
# removed column :  spread2.STD(status.PPE)
# removed column :  spread2.STD(status.RPDE)
# removed column :  spread2.STD(status.avg_fre)
# removed column :  spread2.STD(status.max_fre)
# removed column :  spread2.STD(status.min_fre)
# removed column :  spread2.STD(status.spread1)
# removed column :  spread2.STD(status.var_amp1)
# removed column :  spread2.STD(status.var_amp2)
# removed column :  spread2.STD(status.var_amp3)
# removed column :  spread2.STD(status.var_amp4)
# removed column :  spread2.STD(status.var_amp5)
# removed column :  spread2.STD(status.var_amp6)
# removed column :  spread2.STD(status.var_fre1)
# removed column :  spread2.STD(status.var_fre2)
# removed column :  spread2.STD(status.var_fre3)
# removed column :  spread2.STD(status.var_fre4)
# removed column :  spread2.STD(status.var_fre5)
# removed column :  D2.SKEW(status.DFA)
# removed column :  D2.SKEW(status.HNR)
# removed column :  D2.SKEW(status.NHR)
# removed column :  D2.SKEW(status.PPE)
# removed column :  D2.SKEW(status.RPDE)
# removed column :  D2.SKEW(status.avg_fre)
# removed column :  D2.SKEW(status.max_fre)
# removed column :  D2.SKEW(status.min_fre)
# removed column :  D2.SKEW(status.spread1)
# removed column :  D2.SKEW(status.spread2)
# removed column :  D2.SKEW(status.var_amp1)
# removed column :  D2.SKEW(status.var_amp2)
# removed column :  D2.SKEW(status.var_amp3)
# removed column :  D2.SKEW(status.var_amp4)
# removed column :  D2.SKEW(status.var_amp5)
# removed column :  D2.SKEW(status.var_amp6)
# removed column :  D2.SKEW(status.var_fre1)
# removed column :  D2.SKEW(status.var_fre2)
# removed column :  D2.SKEW(status.var_fre3)
# removed column :  D2.SKEW(status.var_fre4)
# removed column :  D2.SKEW(status.var_fre5)
# removed column :  D2.STD(status.DFA)
# removed column :  D2.STD(status.HNR)
# removed column :  D2.STD(status.NHR)
# removed column :  D2.STD(status.PPE)
# removed column :  D2.STD(status.RPDE)
# removed column :  D2.STD(status.avg_fre)
# removed column :  D2.STD(status.max_fre)
# removed column :  D2.STD(status.min_fre)
# removed column :  D2.STD(status.spread1)
# removed column :  D2.STD(status.spread2)
# removed column :  D2.STD(status.var_amp1)
# removed column :  D2.STD(status.var_amp2)
# removed column :  D2.STD(status.var_amp3)
# removed column :  D2.STD(status.var_amp4)
# removed column :  D2.STD(status.var_amp5)
# removed column :  D2.STD(status.var_amp6)
# removed column :  D2.STD(status.var_fre1)
# removed column :  D2.STD(status.var_fre2)
# removed column :  D2.STD(status.var_fre3)
# removed column :  D2.STD(status.var_fre4)
# removed column :  D2.STD(status.var_fre5)
# removed column :  PPE.SKEW(status.D2)
# removed column :  PPE.SKEW(status.DFA)
# removed column :  PPE.SKEW(status.HNR)
# removed column :  PPE.SKEW(status.NHR)
# removed column :  PPE.SKEW(status.RPDE)
# removed column :  PPE.SKEW(status.avg_fre)
# removed column :  PPE.SKEW(status.max_fre)
# removed column :  PPE.SKEW(status.min_fre)
# removed column :  PPE.SKEW(status.spread1)
# removed column :  PPE.SKEW(status.spread2)
# removed column :  PPE.SKEW(status.var_amp1)
# removed column :  PPE.SKEW(status.var_amp2)
# removed column :  PPE.SKEW(status.var_amp3)
# removed column :  PPE.SKEW(status.var_amp4)
# removed column :  PPE.SKEW(status.var_amp5)
# removed column :  PPE.SKEW(status.var_amp6)
# removed column :  PPE.SKEW(status.var_fre1)
# removed column :  PPE.SKEW(status.var_fre2)
# removed column :  PPE.SKEW(status.var_fre3)
# removed column :  PPE.SKEW(status.var_fre4)
# removed column :  PPE.SKEW(status.var_fre5)
# removed column :  PPE.STD(status.D2)
# removed column :  PPE.STD(status.DFA)
# removed column :  PPE.STD(status.HNR)
# removed column :  PPE.STD(status.NHR)
# removed column :  PPE.STD(status.RPDE)
# removed column :  PPE.STD(status.avg_fre)
# removed column :  PPE.STD(status.max_fre)
# removed column :  PPE.STD(status.min_fre)
# removed column :  PPE.STD(status.spread1)
# removed column :  PPE.STD(status.spread2)
# removed column :  PPE.STD(status.var_amp1)
# removed column :  PPE.STD(status.var_amp2)
# removed column :  PPE.STD(status.var_amp3)
# removed column :  PPE.STD(status.var_amp4)
# removed column :  PPE.STD(status.var_amp5)
# removed column :  PPE.STD(status.var_amp6)
# removed column :  PPE.STD(status.var_fre1)
# removed column :  PPE.STD(status.var_fre2)
# removed column :  PPE.STD(status.var_fre3)
# removed column :  PPE.STD(status.var_fre4)
# removed column :  PPE.STD(status.var_fre5)
# Data imputation successfull
#      avg_fre  max_fre  min_fre  var_fre1  var_fre2  var_fre3  var_fre4  \
# id
# 0       0.46     0.27     0.31      0.24      0.27      0.17      0.28
# 1       0.47     0.25     0.48      0.29      0.31      0.22      0.36
# 2       0.45     0.22     0.47      0.32      0.35      0.25      0.40
# 3       0.45     0.23     0.47      0.30      0.35      0.23      0.36
# 4       0.45     0.24     0.46      0.39      0.42      0.31      0.46
# ..       ...      ...      ...       ...       ...       ...       ...
# 190     0.67     0.39     0.39      0.14      0.12      0.12      0.13
# 191     0.81     0.43     0.37      0.17      0.12      0.15      0.15
# 192     0.67     0.41     0.31      0.41      0.31      0.29      0.29
# 193     0.76     0.67     0.31      0.22      0.15      0.17      0.20
# 194     0.82     0.44     0.33      0.17      0.12      0.14      0.16
#
#      var_fre5  var_amp1  var_amp2  var_amp3  var_amp4  var_amp5  var_amp6  \
# id
# 0        0.17      0.37      0.33      0.39      0.39      0.22      0.39
# 1        0.22      0.52      0.48      0.55      0.57      0.32      0.56
# 2        0.25      0.44      0.37      0.49      0.49      0.26      0.49
# 3        0.23      0.46      0.40      0.52      0.50      0.27      0.52
# 4        0.31      0.54      0.45      0.62      0.61      0.32      0.62
# ..        ...       ...       ...       ...       ...       ...       ...
# 190      0.12      0.34      0.31      0.41      0.31      0.20      0.41
# 191      0.15      0.23      0.20      0.28      0.21      0.14      0.28
# 192      0.29      0.19      0.20      0.22      0.17      0.12      0.22
# 193      0.17      0.19      0.19      0.22      0.17      0.12      0.22
# 194      0.14      0.16      0.15      0.18      0.15      0.10      0.18
#
#      NHR  HNR  RPDE  DFA  spread1  spread2   D2  PPE  avg_fre.COUNT(status)  \
# id
# 0   0.07 0.64  0.61 0.99     1.98     0.59 0.63 0.54                      1
# 1   0.06 0.58  0.67 0.99     1.67     0.74 0.68 0.70                      1
# 2   0.04 0.62  0.63 1.00     1.83     0.69 0.64 0.63                      1
# 3   0.04 0.62  0.63 0.99     1.69     0.74 0.66 0.70                      1
# 4   0.06 0.59  0.61 1.00     1.54     0.52 0.64 0.78                      1
# ..   ...  ...   ...  ...      ...      ...  ...  ...                    ...
# 190 0.09 0.59  0.65 0.80     2.69     0.27 0.72 0.25                      1
# 191 0.06 0.58  0.63 0.83     2.55     0.29 0.76 0.32                      1
# 192 0.34 0.54  0.59 0.79     2.79     0.35 0.73 0.25                      1
# 193 0.23 0.58  0.66 0.78     2.77     0.46 0.58 0.23                      1
# 194 0.14 0.64  0.68 0.81     2.35     0.42 0.70 0.28                      1
#
#      avg_fre.MAX(status.D2)  avg_fre.MAX(status.DFA)  avg_fre.MAX(status.HNR)  \
# id
# 0                      0.63                     0.99                     0.64
# 1                      0.68                     0.99                     0.58
# 2                      0.64                     1.00                     0.62
# 3                      0.66                     0.99                     0.62
# 4                      0.64                     1.00                     0.59
# ..                      ...                      ...                      ...
# 190                    0.72                     0.80                     0.59
# 191                    0.76                     0.83                     0.58
# 192                    0.73                     0.79                     0.54
# 193                    0.58                     0.78                     0.58
# 194                    0.70                     0.81                     0.64
#
#      avg_fre.MAX(status.NHR)  avg_fre.MAX(status.PPE)  \
# id
# 0                       0.07                     0.54
# 1                       0.06                     0.70
# 2                       0.04                     0.63
# 3                       0.04                     0.70
# 4                       0.06                     0.78
# ..                       ...                      ...
# 190                     0.09                     0.25
# 191                     0.06                     0.32
# 192                     0.34                     0.25
# 193                     0.23                     0.23
# 194                     0.14                     0.28
#
#      avg_fre.MAX(status.RPDE)  avg_fre.MAX(status.max_fre)  \
# id
# 0                        0.61                         0.27
# 1                        0.67                         0.25
# 2                        0.63                         0.22
# 3                        0.63                         0.23
# 4                        0.61                         0.24
# ..                        ...                          ...
# 190                      0.65                         0.39
# 191                      0.63                         0.43
# 192                      0.59                         0.41
# 193                      0.66                         0.67
# 194                      0.68                         0.44
#
#      avg_fre.MAX(status.min_fre)  avg_fre.MAX(status.spread1)  \
# ...
# ..                         ...                        ...
# 190                       0.12                       0.13
# 191                       0.15                       0.15
# 192                       0.29                       0.29
# 193                       0.17                       0.20
# 194                       0.14                       0.16
#
#      PPE.MEAN(status.var_fre5)  PPE.MIN(status.D2)  PPE.MIN(status.DFA)  \
# id
# 0                         0.17                0.63                 0.99
# 1                         0.22                0.68                 0.99
# 2                         0.25                0.64                 1.00
# 3                         0.23                0.66                 0.99
# 4                         0.31                0.64                 1.00
# ..                         ...                 ...                  ...
# 190                       0.12                0.72                 0.80
# 191                       0.15                0.76                 0.83
# 192                       0.29                0.73                 0.79
# 193                       0.17                0.58                 0.78
# 194                       0.14                0.70                 0.81
#
#      PPE.MIN(status.HNR)  PPE.MIN(status.NHR)  PPE.MIN(status.RPDE)  \
# id
# 0                   0.64                 0.07                  0.61
# 1                   0.58                 0.06                  0.67
# 2                   0.62                 0.04                  0.63
# 3                   0.62                 0.04                  0.63
# 4                   0.59                 0.06                  0.61
# ..                   ...                  ...                   ...
# 190                 0.59                 0.09                  0.65
# 191                 0.58                 0.06                  0.63
# 192                 0.54                 0.34                  0.59
# 193                 0.58                 0.23                  0.66
# 194                 0.64                 0.14                  0.68
#
#      PPE.MIN(status.avg_fre)  PPE.MIN(status.max_fre)  \
# id
# 0                       0.46                     0.27
# 1                       0.47                     0.25
# 2                       0.45                     0.22
# 3                       0.45                     0.23
# 4                       0.45                     0.24
# ..                       ...                      ...
# 190                     0.67                     0.39
# 191                     0.81                     0.43
# 192                     0.67                     0.41
# 193                     0.76                     0.67
# 194                     0.82                     0.44
#
#      PPE.MIN(status.min_fre)  PPE.MIN(status.spread1)  \
# id
# 0                       0.31                     1.98
# 1                       0.48                     1.67
# 2                       0.47                     1.83
# 3                       0.47                     1.69
# 4                       0.46                     1.54
# ..                       ...                      ...
# 190                     0.39                     2.69
# 191                     0.37                     2.55
# 192                     0.31                     2.79
# 193                     0.31                     2.77
# 194                     0.33                     2.35
#
#      PPE.MIN(status.spread2)  PPE.MIN(status.var_amp1)  \
# id
# 0                       0.59                      0.37
# 1                       0.74                      0.52
# 2                       0.69                      0.44
# 3                       0.74                      0.46
# 4                       0.52                      0.54
# ..                       ...                       ...
# 190                     0.27                      0.34
# 191                     0.29                      0.23
# 192                     0.35                      0.19
# 193                     0.46                      0.19
# 194                     0.42                      0.16
#
#      PPE.MIN(status.var_amp2)  PPE.MIN(status.var_amp3)  \
# id
# 0                        0.33                      0.39
# 1                        0.48                      0.55
# 2                        0.37                      0.49
# 3                        0.40                      0.52
# 4                        0.45                      0.62
# ..                        ...                       ...
# 190                      0.31                      0.41
# 191                      0.20                      0.28
# 192                      0.20                      0.22
# 193                      0.19                      0.22
# 194                      0.15                      0.18
#
#      PPE.MIN(status.var_amp4)  PPE.MIN(status.var_amp5)  \
# id
# 0                        0.39                      0.22
# 1                        0.57                      0.32
# 2                        0.49                      0.26
# 3                        0.50                      0.27
# 4                        0.61                      0.32
# ..                        ...                       ...
# 190                      0.31                      0.20
# 191                      0.21                      0.14
# 192                      0.17                      0.12
# 193                      0.17                      0.12
# 194                      0.15                      0.10
#
#      PPE.MIN(status.var_amp6)  PPE.MIN(status.var_fre1)  \
# id
# 0                        0.39                      0.24
# 1                        0.56                      0.29
# 2                        0.49                      0.32
# 3                        0.52                      0.30
# 4                        0.62                      0.39
# ..                        ...                       ...
# 190                      0.41                      0.14
# 191                      0.28                      0.17
# 192                      0.22                      0.41
# 193                      0.22                      0.22
# 194                      0.18                      0.17
#
#      PPE.MIN(status.var_fre2)  PPE.MIN(status.var_fre3)  \
# id
# 0                        0.27                      0.17
# 1                        0.31                      0.22
# 2                        0.35                      0.25
# 3                        0.35                      0.23
# 4                        0.42                      0.31
# ..                        ...                       ...
# 190                      0.12                      0.12
# 191                      0.12                      0.15
# 192                      0.31                      0.29
# 193                      0.15                      0.17
# 194                      0.12                      0.14
#
#      PPE.MIN(status.var_fre4)  PPE.MIN(status.var_fre5)  PPE.SUM(status.D2)  \
# id
# 0                        0.28                      0.17                0.63
# 1                        0.36                      0.22                0.68
# 2                        0.40                      0.25                0.64
# 3                        0.36                      0.23                0.66
# 4                        0.46                      0.31                0.64
# ..                        ...                       ...                 ...
# 190                      0.13                      0.12                0.72
# 191                      0.15                      0.15                0.76
# 192                      0.29                      0.29                0.73
# 193                      0.20                      0.17                0.58
# 194                      0.16                      0.14                0.70
#
#      PPE.SUM(status.DFA)  PPE.SUM(status.HNR)  PPE.SUM(status.NHR)  \
# id
# 0                   0.99                 0.64                 0.07
# 1                   0.99                 0.58                 0.06
# 2                   1.00                 0.62                 0.04
# 3                   0.99                 0.62                 0.04
# 4                   1.00                 0.59                 0.06
# ..                   ...                  ...                  ...
# 190                 0.80                 0.59                 0.09
# 191                 0.83                 0.58                 0.06
# 192                 0.79                 0.54                 0.34
# 193                 0.78                 0.58                 0.23
# 194                 0.81                 0.64                 0.14
#
#      PPE.SUM(status.RPDE)  PPE.SUM(status.avg_fre)  PPE.SUM(status.max_fre)  \
# id
# 0                    0.61                     0.46                     0.27
# 1                    0.67                     0.47                     0.25
# 2                    0.63                     0.45                     0.22
# 3                    0.63                     0.45                     0.23
# 4                    0.61                     0.45                     0.24
# ..                    ...                      ...                      ...
# 190                  0.65                     0.67                     0.39
# 191                  0.63                     0.81                     0.43
# 192                  0.59                     0.67                     0.41
# 193                  0.66                     0.76                     0.67
# 194                  0.68                     0.82                     0.44
#
#      PPE.SUM(status.min_fre)  PPE.SUM(status.spread1)  \
# id
# 0                       0.31                     1.98
# 1                       0.48                     1.67
# 2                       0.47                     1.83
# 3                       0.47                     1.69
# 4                       0.46                     1.54
# ..                       ...                      ...
# 190                     0.39                     2.69
# 191                     0.37                     2.55
# 192                     0.31                     2.79
# 193                     0.31                     2.77
# 194                     0.33                     2.35
#
#      PPE.SUM(status.spread2)  PPE.SUM(status.var_amp1)  \
# id
# 0                       0.59                      0.37
# 1                       0.74                      0.52
# 2                       0.69                      0.44
# 3                       0.74                      0.46
# 4                       0.52                      0.54
# ..                       ...                       ...
# 190                     0.27                      0.34
# 191                     0.29                      0.23
# 192                     0.35                      0.19
# 193                     0.46                      0.19
# 194                     0.42                      0.16
#
#      PPE.SUM(status.var_amp2)  PPE.SUM(status.var_amp3)  \
# id
# 0                        0.33                      0.39
# 1                        0.48                      0.55
# 2                        0.37                      0.49
# 3                        0.40                      0.52
# 4                        0.45                      0.62
# ..                        ...                       ...
# 190                      0.31                      0.41
# 191                      0.20                      0.28
# 192                      0.20                      0.22
# 193                      0.19                      0.22
# 194                      0.15                      0.18
#
#      PPE.SUM(status.var_amp4)  PPE.SUM(status.var_amp5)  \
# id
# 0                        0.39                      0.22
# 1                        0.57                      0.32
# 2                        0.49                      0.26
# 3                        0.50                      0.27
# 4                        0.61                      0.32
# ..                        ...                       ...
# 190                      0.31                      0.20
# 191                      0.21                      0.14
# 192                      0.17                      0.12
# 193                      0.17                      0.12
# 194                      0.15                      0.10
#
#      PPE.SUM(status.var_amp6)  PPE.SUM(status.var_fre1)  \
# id
# 0                        0.39                      0.24
# 1                        0.56                      0.29
# 2                        0.49                      0.32
# 3                        0.52                      0.30
# 4                        0.62                      0.39
# ..                        ...                       ...
# 190                      0.41                      0.14
# 191                      0.28                      0.17
# 192                      0.22                      0.41
# 193                      0.22                      0.22
# 194                      0.18                      0.17
#
#      PPE.SUM(status.var_fre2)  PPE.SUM(status.var_fre3)  \
# id
# 0                        0.27                      0.17
# 1                        0.31                      0.22
# 2                        0.35                      0.25
# 3                        0.35                      0.23
# 4                        0.42                      0.31
# ..                        ...                       ...
# 190                      0.12                      0.12
# 191                      0.12                      0.15
# 192                      0.31                      0.29
# 193                      0.15                      0.17
# 194                      0.12                      0.14
#
#      PPE.SUM(status.var_fre4)  PPE.SUM(status.var_fre5)  status
# id
# 0                        0.28                      0.17       1
# 1                        0.36                      0.22       1
# 2                        0.40                      0.25       1
# 3                        0.36                      0.23       1
# 4                        0.46                      0.31       1
# ..                        ...                       ...     ...
# 190                      0.13                      0.12       0
# 191                      0.15                      0.15       0
# 192                      0.29                      0.29       0
# 193                      0.20                      0.17       0
# 194                      0.16                      0.14       0
#
# [195 rows x 1935 columns]

# %% [markdown]
# # Filtering Feature Matrix

# %%
def filter_data(feature_matrix,target_ID):
    lasso_feat = select_lasso_optu(feature_matrix,target_ID,objective,n_trials=50)
    lasso_feat  =[t for t in lasso_feat if t != target_ID]
    pearson_feat = select_pearson_feat(feature_matrix,target_ID,thr=0.05) #pearson
    pearson_feat  =[t for t in pearson_feat if t != target_ID]
    lasso_pearson_feats = list(set(pearson_feat).intersection(set(lasso_feat)))
    feats = lasso_pearson_feats+[target_ID]
    return feats

def objective(trial):
    alpha = trial.suggest_uniform('alpha',0.0,2.0)
    X,y,_ = get_data(feature_matrix)
    lasso_model = Lasso(alpha=alpha)
    acc = cross_val_score(lasso_model,X , y,scoring='r2',cv=5).mean()
    acc = -acc
    return acc

def select_lasso_optu(feature_matrix,target_id,objective,n_trials=20):
    X,y,cols = get_data(feature_matrix)
    study = optuna.create_study(direction='minimize')
    study.optimize(objective,n_trials=n_trials)
    lasso_model = Lasso(**study.best_params)
    lasso_model.fit(X,y)
    coeff = np.abs(lasso_model.coef_)
    feats = np.array(cols)[coeff>0].tolist()
    feats = feats+[target_ID]
    return feats

def select_genetic_feat(feature_matrix,target_ID,f_count):
    estimator = DecisionTreeClassifier()
    X,y = feature_matrix.drop(labels=[target_ID],axis=1),feature_matrix[target_ID]
    model = GeneticSelectionCV(
        estimator, cv=5, verbose=0,
        scoring="accuracy", max_features=f_count,
        n_population=100, crossover_proba=0.5,
        mutation_proba=0.2, n_generations=50,
        crossover_independent_proba=0.5,
        mutation_independent_proba=0.04,
        tournament_size=3, n_gen_no_change=10,
        caching=True, n_jobs=-1)

    model = model.fit(X, y)
#     print('Features:', X.columns[model.support_])
    feats = list(X.columns[model.support_])+[target_ID]
    return feats


def get_data(feature_matrix):
    sc = StandardScaler()
    X,y = feature_matrix.drop(labels=[target_ID],axis=1),feature_matrix[target_ID]
    cols = X.columns
    X = sc.fit_transform(X)
    return X,y,cols


def select_pearson_feat(feature_matrix,ID,thr=0.15):
    cols =[]
    for t in feature_matrix.columns:
        try:
            corr,_ = pearsonr(feature_matrix[ID],feature_matrix[t])
            if corr > thr:
                print(corr,t)
                cols.append(t)
        except:
            pass
    return cols

# %%
feats = filter_data(feature_matrix,target_ID)
feats
# Out:
# 0.2782195982792975 var_fre1
# 0.3386530980793471 var_fre2
# 0.2666675565341965 var_fre3
# 0.2886983466906385 var_fre4
# 0.2666460942115801 var_fre5
# 0.3674298598935416 var_amp1
# 0.3506969057174749 var_amp2
# 0.34761696522403307 var_amp3
# 0.3511484359380265 var_amp4
# 0.36431573922311206 var_amp5
# 0.3476083545379774 var_amp6
# 0.18942931888728265 NHR
# 0.30856725130270324 RPDE
# 0.23173927276037898 DFA
# 0.4548421261086427 spread2
# 0.34023150988036344 D2
# 0.5310391538731206 PPE
# 0.34023150988036344 avg_fre.MAX(status.D2)
# 0.23173927276037898 avg_fre.MAX(status.DFA)
# 0.18942931888728265 avg_fre.MAX(status.NHR)
# 0.5310391538731206 avg_fre.MAX(status.PPE)
# 0.30856725130270324 avg_fre.MAX(status.RPDE)
# 0.4548421261086427 avg_fre.MAX(status.spread2)
# 0.3674298598935416 avg_fre.MAX(status.var_amp1)
# 0.3506969057174749 avg_fre.MAX(status.var_amp2)
# 0.34761696522403307 avg_fre.MAX(status.var_amp3)
# 0.3511484359380265 avg_fre.MAX(status.var_amp4)
# 0.36431573922311206 avg_fre.MAX(status.var_amp5)
# 0.3476083545379774 avg_fre.MAX(status.var_amp6)
# 0.2782195982792975 avg_fre.MAX(status.var_fre1)
# 0.3386530980793471 avg_fre.MAX(status.var_fre2)
# 0.2666675565341965 avg_fre.MAX(status.var_fre3)
# 0.2886983466906385 avg_fre.MAX(status.var_fre4)
# 0.2666460942115801 avg_fre.MAX(status.var_fre5)
# 0.34023150988036344 avg_fre.MEAN(status.D2)
# 0.23173927276037898 avg_fre.MEAN(status.DFA)
# 0.18942931888728265 avg_fre.MEAN(status.NHR)
# 0.5310391538731206 avg_fre.MEAN(status.PPE)
# 0.30856725130270324 avg_fre.MEAN(status.RPDE)
# 0.4548421261086427 avg_fre.MEAN(status.spread2)
# 0.3674298598935416 avg_fre.MEAN(status.var_amp1)
# 0.3506969057174749 avg_fre.MEAN(status.var_amp2)
# 0.34761696522403307 avg_fre.MEAN(status.var_amp3)
# 0.3511484359380265 avg_fre.MEAN(status.var_amp4)
# 0.36431573922311206 avg_fre.MEAN(status.var_amp5)
# 0.3476083545379774 avg_fre.MEAN(status.var_amp6)
# 0.2782195982792975 avg_fre.MEAN(status.var_fre1)
# 0.3386530980793471 avg_fre.MEAN(status.var_fre2)
# 0.2666675565341965 avg_fre.MEAN(status.var_fre3)
# 0.2886983466906385 avg_fre.MEAN(status.var_fre4)
# 0.2666460942115801 avg_fre.MEAN(status.var_fre5)
# 0.34023150988036344 avg_fre.MIN(status.D2)
# 0.23173927276037898 avg_fre.MIN(status.DFA)
# 0.18942931888728265 avg_fre.MIN(status.NHR)
# 0.5310391538731206 avg_fre.MIN(status.PPE)
# 0.30856725130270324 avg_fre.MIN(status.RPDE)
# 0.4548421261086427 avg_fre.MIN(status.spread2)
# 0.3674298598935416 avg_fre.MIN(status.var_amp1)
# 0.3506969057174749 avg_fre.MIN(status.var_amp2)
# 0.34761696522403307 avg_fre.MIN(status.var_amp3)
# 0.3511484359380265 avg_fre.MIN(status.var_amp4)
# 0.36431573922311206 avg_fre.MIN(status.var_amp5)
# 0.3476083545379774 avg_fre.MIN(status.var_amp6)
# 0.2782195982792975 avg_fre.MIN(status.var_fre1)
# 0.3386530980793471 avg_fre.MIN(status.var_fre2)
# 0.2666675565341965 avg_fre.MIN(status.var_fre3)
# 0.2886983466906385 avg_fre.MIN(status.var_fre4)
# 0.2666460942115801 avg_fre.MIN(status.var_fre5)
# 0.34023150988036344 avg_fre.SUM(status.D2)
# 0.23173927276037898 avg_fre.SUM(status.DFA)
# 0.18942931888728265 avg_fre.SUM(status.NHR)
# 0.5310391538731206 avg_fre.SUM(status.PPE)
# 0.30856725130270324 avg_fre.SUM(status.RPDE)
# 0.4548421261086427 avg_fre.SUM(status.spread2)
# 0.3674298598935416 avg_fre.SUM(status.var_amp1)
# 0.3506969057174749 avg_fre.SUM(status.var_amp2)
# 0.34761696522403307 avg_fre.SUM(status.var_amp3)
# 0.3511484359380265 avg_fre.SUM(status.var_amp4)
# 0.36431573922311206 avg_fre.SUM(status.var_amp5)
# 0.3476083545379774 avg_fre.SUM(status.var_amp6)
# 0.2782195982792975 avg_fre.SUM(status.var_fre1)
# 0.3386530980793471 avg_fre.SUM(status.var_fre2)
# 0.2666675565341965 avg_fre.SUM(status.var_fre3)
# 0.2886983466906385 avg_fre.SUM(status.var_fre4)
# 0.2666460942115801 avg_fre.SUM(status.var_fre5)
# 0.34023150988036344 max_fre.MAX(status.D2)
# 0.23173927276037898 max_fre.MAX(status.DFA)
# 0.18942931888728265 max_fre.MAX(status.NHR)
# 0.5310391538731206 max_fre.MAX(status.PPE)
# 0.30856725130270324 max_fre.MAX(status.RPDE)
# 0.4548421261086427 max_fre.MAX(status.spread2)
# 0.3674298598935416 max_fre.MAX(status.var_amp1)
# 0.3506969057174749 max_fre.MAX(status.var_amp2)
# 0.34761696522403307 max_fre.MAX(status.var_amp3)
# 0.3511484359380265 max_fre.MAX(status.var_amp4)
# 0.36431573922311206 max_fre.MAX(status.var_amp5)
# 0.3476083545379774 max_fre.MAX(status.var_amp6)
# 0.2782195982792975 max_fre.MAX(status.var_fre1)
# 0.3386530980793471 max_fre.MAX(status.var_fre2)
# 0.2666675565341965 max_fre.MAX(status.var_fre3)
# 0.2886983466906385 max_fre.MAX(status.var_fre4)
# 0.2666460942115801 max_fre.MAX(status.var_fre5)
# 0.34023150988036344 max_fre.MEAN(status.D2)
# 0.23173927276037898 max_fre.MEAN(status.DFA)
# 0.18942931888728265 max_fre.MEAN(status.NHR)
# 0.5310391538731206 max_fre.MEAN(status.PPE)
# 0.30856725130270324 max_fre.MEAN(status.RPDE)
# 0.4548421261086427 max_fre.MEAN(status.spread2)
# 0.3674298598935416 max_fre.MEAN(status.var_amp1)
# 0.3506969057174749 max_fre.MEAN(status.var_amp2)
# 0.34761696522403307 max_fre.MEAN(status.var_amp3)
# 0.3511484359380265 max_fre.MEAN(status.var_amp4)
# 0.36431573922311206 max_fre.MEAN(status.var_amp5)
# 0.3476083545379774 max_fre.MEAN(status.var_amp6)
# 0.2782195982792975 max_fre.MEAN(status.var_fre1)
# 0.3386530980793471 max_fre.MEAN(status.var_fre2)
# 0.2666675565341965 max_fre.MEAN(status.var_fre3)
# 0.2886983466906385 max_fre.MEAN(status.var_fre4)
# 0.2666460942115801 max_fre.MEAN(status.var_fre5)
# 0.34023150988036344 max_fre.MIN(status.D2)
# 0.23173927276037898 max_fre.MIN(status.DFA)
# 0.18942931888728265 max_fre.MIN(status.NHR)
# 0.5310391538731206 max_fre.MIN(status.PPE)
# 0.30856725130270324 max_fre.MIN(status.RPDE)
# 0.4548421261086427 max_fre.MIN(status.spread2)
# 0.3674298598935416 max_fre.MIN(status.var_amp1)
# 0.3506969057174749 max_fre.MIN(status.var_amp2)
# 0.34761696522403307 max_fre.MIN(status.var_amp3)
# 0.3511484359380265 max_fre.MIN(status.var_amp4)
# 0.36431573922311206 max_fre.MIN(status.var_amp5)
# 0.3476083545379774 max_fre.MIN(status.var_amp6)
# 0.2782195982792975 max_fre.MIN(status.var_fre1)
# 0.3386530980793471 max_fre.MIN(status.var_fre2)
# 0.2666675565341965 max_fre.MIN(status.var_fre3)
# 0.2886983466906385 max_fre.MIN(status.var_fre4)
# 0.2666460942115801 max_fre.MIN(status.var_fre5)
# 0.34023150988036344 max_fre.SUM(status.D2)
# 0.23173927276037898 max_fre.SUM(status.DFA)
# 0.18942931888728265 max_fre.SUM(status.NHR)
# 0.5310391538731206 max_fre.SUM(status.PPE)
# 0.30856725130270324 max_fre.SUM(status.RPDE)
# 0.4548421261086427 max_fre.SUM(status.spread2)
# 0.3674298598935416 max_fre.SUM(status.var_amp1)
# 0.3506969057174749 max_fre.SUM(status.var_amp2)
# 0.34761696522403307 max_fre.SUM(status.var_amp3)
# 0.3511484359380265 max_fre.SUM(status.var_amp4)
# 0.36431573922311206 max_fre.SUM(status.var_amp5)
# 0.3476083545379774 max_fre.SUM(status.var_amp6)
# 0.2782195982792975 max_fre.SUM(status.var_fre1)
# 0.3386530980793471 max_fre.SUM(status.var_fre2)
# 0.2666675565341965 max_fre.SUM(status.var_fre3)
# 0.2886983466906385 max_fre.SUM(status.var_fre4)
# 0.2666460942115801 max_fre.SUM(status.var_fre5)
# 0.34023150988036344 min_fre.MAX(status.D2)
# 0.23173927276037898 min_fre.MAX(status.DFA)
# 0.18942931888728265 min_fre.MAX(status.NHR)
# 0.5310391538731206 min_fre.MAX(status.PPE)
# 0.30856725130270324 min_fre.MAX(status.RPDE)
# 0.4548421261086427 min_fre.MAX(status.spread2)
# 0.3674298598935416 min_fre.MAX(status.var_amp1)
# 0.3506969057174749 min_fre.MAX(status.var_amp2)
# 0.34761696522403307 min_fre.MAX(status.var_amp3)
# 0.3511484359380265 min_fre.MAX(status.var_amp4)
# 0.36431573922311206 min_fre.MAX(status.var_amp5)
# 0.3476083545379774 min_fre.MAX(status.var_amp6)
# 0.2782195982792975 min_fre.MAX(status.var_fre1)
# 0.3386530980793471 min_fre.MAX(status.var_fre2)
# 0.2666675565341965 min_fre.MAX(status.var_fre3)
# 0.2886983466906385 min_fre.MAX(status.var_fre4)
# 0.2666460942115801 min_fre.MAX(status.var_fre5)
# 0.34023150988036344 min_fre.MEAN(status.D2)
# 0.23173927276037898 min_fre.MEAN(status.DFA)
# 0.18942931888728265 min_fre.MEAN(status.NHR)
# 0.5310391538731206 min_fre.MEAN(status.PPE)
# 0.30856725130270324 min_fre.MEAN(status.RPDE)
# 0.4548421261086427 min_fre.MEAN(status.spread2)
# 0.3674298598935416 min_fre.MEAN(status.var_amp1)
# 0.3506969057174749 min_fre.MEAN(status.var_amp2)
# 0.34761696522403307 min_fre.MEAN(status.var_amp3)
# 0.3511484359380265 min_fre.MEAN(status.var_amp4)
# 0.36431573922311206 min_fre.MEAN(status.var_amp5)
# 0.3476083545379774 min_fre.MEAN(status.var_amp6)
# 0.2782195982792975 min_fre.MEAN(status.var_fre1)
# 0.3386530980793471 min_fre.MEAN(status.var_fre2)
# 0.2666675565341965 min_fre.MEAN(status.var_fre3)
# 0.2886983466906385 min_fre.MEAN(status.var_fre4)
# 0.2666460942115801 min_fre.MEAN(status.var_fre5)
# 0.34023150988036344 min_fre.MIN(status.D2)
# 0.23173927276037898 min_fre.MIN(status.DFA)
# 0.18942931888728265 min_fre.MIN(status.NHR)
# 0.5310391538731206 min_fre.MIN(status.PPE)
# 0.30856725130270324 min_fre.MIN(status.RPDE)
# 0.4548421261086427 min_fre.MIN(status.spread2)
# 0.3674298598935416 min_fre.MIN(status.var_amp1)
# 0.3506969057174749 min_fre.MIN(status.var_amp2)
# 0.34761696522403307 min_fre.MIN(status.var_amp3)
# 0.3511484359380265 min_fre.MIN(status.var_amp4)
# 0.36431573922311206 min_fre.MIN(status.var_amp5)
# 0.3476083545379774 min_fre.MIN(status.var_amp6)
# 0.2782195982792975 min_fre.MIN(status.var_fre1)
# 0.3386530980793471 min_fre.MIN(status.var_fre2)
# 0.2666675565341965 min_fre.MIN(status.var_fre3)
# 0.2886983466906385 min_fre.MIN(status.var_fre4)
# 0.2666460942115801 min_fre.MIN(status.var_fre5)
# 0.34023150988036344 min_fre.SUM(status.D2)
# 0.23173927276037898 min_fre.SUM(status.DFA)
# 0.18942931888728265 min_fre.SUM(status.NHR)
# 0.5310391538731206 min_fre.SUM(status.PPE)
# 0.30856725130270324 min_fre.SUM(status.RPDE)
# 0.4548421261086427 min_fre.SUM(status.spread2)
# 0.3674298598935416 min_fre.SUM(status.var_amp1)
# 0.3506969057174749 min_fre.SUM(status.var_amp2)
# 0.34761696522403307 min_fre.SUM(status.var_amp3)
# 0.3511484359380265 min_fre.SUM(status.var_amp4)
# 0.36431573922311206 min_fre.SUM(status.var_amp5)
# 0.3476083545379774 min_fre.SUM(status.var_amp6)
# 0.2782195982792975 min_fre.SUM(status.var_fre1)
# 0.3386530980793471 min_fre.SUM(status.var_fre2)
# 0.2666675565341965 min_fre.SUM(status.var_fre3)
# 0.2886983466906385 min_fre.SUM(status.var_fre4)
# 0.2666460942115801 min_fre.SUM(status.var_fre5)
# 0.07402429721657827 var_fre1.COUNT(status)
# 0.33490689417721653 var_fre1.MAX(status.D2)
# 0.1960123082278046 var_fre1.MAX(status.DFA)
# 0.1959160497278957 var_fre1.MAX(status.NHR)
# 0.49506271973372656 var_fre1.MAX(status.PPE)
# 0.32764041510020914 var_fre1.MAX(status.RPDE)
# 0.44559186423902364 var_fre1.MAX(status.spread2)
# 0.3534983924119336 var_fre1.MAX(status.var_amp1)
# 0.33892620999930556 var_fre1.MAX(status.var_amp2)
# 0.3382593383527881 var_fre1.MAX(status.var_amp3)
# 0.33519208378620324 var_fre1.MAX(status.var_amp4)
# 0.3487862574086866 var_fre1.MAX(status.var_amp5)
# 0.3382546244422907 var_fre1.MAX(status.var_amp6)
# 0.33252593881338766 var_fre1.MAX(status.var_fre2)
# 0.269120930637942 var_fre1.MAX(status.var_fre3)
# 0.29036984959816 var_fre1.MAX(status.var_fre4)
# 0.26909878536673126 var_fre1.MAX(status.var_fre5)
# 0.32883711419326533 var_fre1.MEAN(status.D2)
# 0.1948033292193777 var_fre1.MEAN(status.DFA)
# 0.19008601798348476 var_fre1.MEAN(status.NHR)
# 0.5085359809890311 var_fre1.MEAN(status.PPE)
# 0.32298843621390266 var_fre1.MEAN(status.RPDE)
# 0.4394299304467688 var_fre1.MEAN(status.spread2)
# 0.3547386835537538 var_fre1.MEAN(status.var_amp1)
# 0.33869862279639334 var_fre1.MEAN(status.var_amp2)
# 0.3363603920070973 var_fre1.MEAN(status.var_amp3)
# 0.33768876703036665 var_fre1.MEAN(status.var_amp4)
# 0.3506153741163361 var_fre1.MEAN(status.var_amp5)
# 0.3363570805342596 var_fre1.MEAN(status.var_amp6)
# 0.33404284088906977 var_fre1.MEAN(status.var_fre2)
# 0.26671230702436116 var_fre1.MEAN(status.var_fre3)
# 0.28732712563304263 var_fre1.MEAN(status.var_fre4)
# 0.26667685079563946 var_fre1.MEAN(status.var_fre5)
# 0.2980322302309272 var_fre1.MIN(status.D2)
# 0.17682835960376647 var_fre1.MIN(status.DFA)
# 0.18260248802121629 var_fre1.MIN(status.NHR)
# 0.49384195254439145 var_fre1.MIN(status.PPE)
# 0.2810076070219634 var_fre1.MIN(status.RPDE)
# 0.4026187515048184 var_fre1.MIN(status.spread2)
# 0.3296040037102037 var_fre1.MIN(status.var_amp1)
# 0.31745106240295945 var_fre1.MIN(status.var_amp2)
# 0.30867902754104476 var_fre1.MIN(status.var_amp3)
# 0.3124429028987727 var_fre1.MIN(status.var_amp4)
# 0.3304814669159283 var_fre1.MIN(status.var_amp5)
# 0.30868043377272353 var_fre1.MIN(status.var_amp6)
# 0.33269045449183726 var_fre1.MIN(status.var_fre2)
# 0.2635231181265782 var_fre1.MIN(status.var_fre3)
# 0.28380087868539083 var_fre1.MIN(status.var_fre4)
# 0.26348753703220595 var_fre1.MIN(status.var_fre5)
# 0.15852683907719706 var_fre1.SUM(status.D2)
# 0.10141417241702248 var_fre1.SUM(status.DFA)
# 0.20180074196203318 var_fre1.SUM(status.NHR)
# 0.3632899512701618 var_fre1.SUM(status.PPE)
# 0.17774156961210869 var_fre1.SUM(status.RPDE)
# 0.3140171609721276 var_fre1.SUM(status.spread2)
# 0.29748435664394124 var_fre1.SUM(status.var_amp1)
# 0.29444324195479 var_fre1.SUM(status.var_amp2)
# 0.2847619001495681 var_fre1.SUM(status.var_amp3)
# 0.2826234101769723 var_fre1.SUM(status.var_amp4)
# 0.30969366336372095 var_fre1.SUM(status.var_amp5)
# 0.28475418549488046 var_fre1.SUM(status.var_amp6)
# 0.332740373069778 var_fre1.SUM(status.var_fre2)
# 0.27675022700865665 var_fre1.SUM(status.var_fre3)
# 0.28629597162217496 var_fre1.SUM(status.var_fre4)
# 0.27671739694034725 var_fre1.SUM(status.var_fre5)
# 0.2258923130376567 var_fre2.MAX(status.D2)
# 0.27761831669201603 var_fre2.MAX(status.DFA)
# 0.27430572861029195 var_fre2.MAX(status.NHR)
# 0.3902799908845541 var_fre2.MAX(status.PPE)
# 0.3856805615198481 var_fre2.MAX(status.RPDE)
# 0.20039895794046522 var_fre2.MAX(status.max_fre)
# 0.3385676689844655 var_fre2.MAX(status.spread2)
# 0.2313574387232001 var_fre2.MAX(status.var_amp1)
# 0.23175167992882992 var_fre2.MAX(status.var_amp2)
# 0.21401107955101842 var_fre2.MAX(status.var_amp3)
# 0.25004694907140795 var_fre2.MAX(status.var_amp4)
# 0.288960939794762 var_fre2.MAX(status.var_amp5)
# 0.21401638942160683 var_fre2.MAX(status.var_amp6)
# 0.32520273191505605 var_fre2.MAX(status.var_fre1)
# 0.31824069829610835 var_fre2.MAX(status.var_fre3)
# 0.31575475605271464 var_fre2.MAX(status.var_fre4)
# 0.31821320286787325 var_fre2.MAX(status.var_fre5)
# 0.36424468920997904 var_fre2.MEAN(status.D2)
# 0.3300330962578843 var_fre2.MEAN(status.DFA)
# 0.20766781457595385 var_fre2.MEAN(status.NHR)
# 0.43220999412897426 var_fre2.MEAN(status.PPE)
# 0.4079237235914892 var_fre2.MEAN(status.RPDE)
# 0.4570914704144152 var_fre2.MEAN(status.spread2)
# 0.31961356209431147 var_fre2.MEAN(status.var_amp1)
# 0.30831177144995303 var_fre2.MEAN(status.var_amp2)
# 0.31377335714166227 var_fre2.MEAN(status.var_amp3)
# 0.3019061234687893 var_fre2.MEAN(status.var_amp4)
# 0.30297013622851204 var_fre2.MEAN(status.var_amp5)
# 0.3137692763379872 var_fre2.MEAN(status.var_amp6)
# 0.29077208794915915 var_fre2.MEAN(status.var_fre1)
# 0.2700955738116465 var_fre2.MEAN(status.var_fre3)
# 0.2870080589390896 var_fre2.MEAN(status.var_fre4)
# 0.2700659739121367 var_fre2.MEAN(status.var_fre5)
# 0.3871891328246989 var_fre2.MIN(status.D2)
# 0.054890892830855804 var_fre2.MIN(status.DFA)
# 0.13293882338255353 var_fre2.MIN(status.NHR)
# 0.3577465254850816 var_fre2.MIN(status.PPE)
# 0.3344155188153324 var_fre2.MIN(status.RPDE)
# 0.3680176003614733 var_fre2.MIN(status.spread2)
# 0.2270736707724172 var_fre2.MIN(status.var_amp1)
# 0.22783349985429957 var_fre2.MIN(status.var_amp2)
# 0.22215881304380133 var_fre2.MIN(status.var_amp3)
# 0.20410963401029517 var_fre2.MIN(status.var_amp4)
# 0.2011958267282034 var_fre2.MIN(status.var_amp5)
# 0.2222398659948178 var_fre2.MIN(status.var_amp6)
# 0.2621650558890573 var_fre2.MIN(status.var_fre1)
# 0.23708021231327278 var_fre2.MIN(status.var_fre3)
# 0.25437715313280024 var_fre2.MIN(status.var_fre4)
# 0.23717868266798167 var_fre2.MIN(status.var_fre5)
# 0.34921918400955043 var_fre2.SKEW(status.D2)
# 0.4788587944348526 var_fre2.SKEW(status.avg_fre)
# 0.4142271068109006 var_fre2.SKEW(status.max_fre)
# 0.05945230745610572 var_fre2.SKEW(status.min_fre)
# 0.11634074229448356 var_fre2.SKEW(status.spread1)
# 0.2261800114867898 var_fre2.SKEW(status.spread2)
# 0.05749954787339273 var_fre2.SKEW(status.var_amp2)
# 0.12590255568114964 var_fre2.SKEW(status.var_amp4)
# 0.3626206599183815 var_fre2.SKEW(status.var_fre1)
# 0.3148645106316875 var_fre2.SKEW(status.var_fre3)
# 0.16887903924095155 var_fre2.SKEW(status.var_fre4)
# 0.31553783528391066 var_fre2.SKEW(status.var_fre5)
# 0.1510841790117283 var_fre2.STD(status.DFA)
# 0.25850156871517405 var_fre2.STD(status.NHR)
# 0.2567999667363933 var_fre2.STD(status.PPE)
# 0.25932168491733903 var_fre2.STD(status.max_fre)
# 0.13624333608023614 var_fre2.STD(status.spread1)
# 0.06168022882029829 var_fre2.STD(status.spread2)
# 0.2018739665305711 var_fre2.STD(status.var_amp1)
# 0.20771166207381586 var_fre2.STD(status.var_amp2)
# 0.1536376360818832 var_fre2.STD(status.var_amp3)
# 0.21427272691853236 var_fre2.STD(status.var_amp4)
# 0.25194568770245085 var_fre2.STD(status.var_amp5)
# 0.1535851343364286 var_fre2.STD(status.var_amp6)
# 0.25316014528887654 var_fre2.STD(status.var_fre1)
# 0.25722064247253734 var_fre2.STD(status.var_fre3)
# 0.23139599652560552 var_fre2.STD(status.var_fre4)
# 0.25688315487046653 var_fre2.STD(status.var_fre5)
# 0.11627324276167196 var_fre2.SUM(status.NHR)
# 0.05349446761187893 var_fre2.SUM(status.var_fre1)
# 0.06626845052704869 var_fre2.SUM(status.var_fre3)
# 0.05708621040458764 var_fre2.SUM(status.var_fre4)
# 0.066172459208794 var_fre2.SUM(status.var_fre5)
# 0.24883755253249207 var_fre3.MAX(status.D2)
# 0.10468174268942645 var_fre3.MAX(status.DFA)
# 0.19382738627230142 var_fre3.MAX(status.NHR)
# 0.4329093059701881 var_fre3.MAX(status.PPE)
# 0.28532294255579527 var_fre3.MAX(status.RPDE)
# 0.29785379708279086 var_fre3.MAX(status.spread2)
# 0.3765037348703835 var_fre3.MAX(status.var_amp1)
# 0.36280392734159017 var_fre3.MAX(status.var_amp2)
# 0.360992557349146 var_fre3.MAX(status.var_amp3)
# 0.3579064676269307 var_fre3.MAX(status.var_amp4)
# 0.36508707367904103 var_fre3.MAX(status.var_amp5)
# 0.3609848969028688 var_fre3.MAX(status.var_amp6)
# 0.27022407455206604 var_fre3.MAX(status.var_fre1)
# 0.3019455065690658 var_fre3.MAX(status.var_fre2)
# 0.28079242440643903 var_fre3.MAX(status.var_fre4)
# 0.2666009539264363 var_fre3.MAX(status.var_fre5)
# 0.2999461814769515 var_fre3.MEAN(status.D2)
# 0.18126653079616223 var_fre3.MEAN(status.DFA)
# 0.19502750410628755 var_fre3.MEAN(status.NHR)
# 0.47210566142922566 var_fre3.MEAN(status.PPE)
# 0.3398542512221595 var_fre3.MEAN(status.RPDE)
# 0.39578078411031925 var_fre3.MEAN(status.spread2)
# 0.37019693252368796 var_fre3.MEAN(status.var_amp1)
# 0.3522995084246114 var_fre3.MEAN(status.var_amp2)
# 0.357460736417114 var_fre3.MEAN(status.var_amp3)
# 0.3522455455989279 var_fre3.MEAN(status.var_amp4)
# 0.35752997237359824 var_fre3.MEAN(status.var_amp5)
# 0.3574514021910361 var_fre3.MEAN(status.var_amp6)
# 0.2747545394873235 var_fre3.MEAN(status.var_fre1)
# 0.31895074826022535 var_fre3.MEAN(status.var_fre2)
# 0.2825864413614914 var_fre3.MEAN(status.var_fre4)
# 0.2666058977035206 var_fre3.MEAN(status.var_fre5)
# 0.3119233147038696 var_fre3.MIN(status.D2)
# 0.23678652207495 var_fre3.MIN(status.DFA)
# 0.19261995125306755 var_fre3.MIN(status.NHR)
# 0.4806361915510885 var_fre3.MIN(status.PPE)
# 0.3469118570561971 var_fre3.MIN(status.RPDE)
# 0.4115481193449203 var_fre3.MIN(status.spread2)
# 0.34046419722918164 var_fre3.MIN(status.var_amp1)
# 0.324946428879134 var_fre3.MIN(status.var_amp2)
# 0.32877695088432396 var_fre3.MIN(status.var_amp3)
# 0.3219142282899889 var_fre3.MIN(status.var_amp4)
# 0.3309102099413299 var_fre3.MIN(status.var_amp5)
# 0.32877648017349276 var_fre3.MIN(status.var_amp6)
# 0.2755097675782922 var_fre3.MIN(status.var_fre1)
# 0.32771350444610436 var_fre3.MIN(status.var_fre2)
# 0.28200303626985923 var_fre3.MIN(status.var_fre4)
# 0.26660642285131814 var_fre3.MIN(status.var_fre5)
# 0.19568201988360992 var_fre3.SUM(status.NHR)
# 0.17788796467023077 var_fre3.SUM(status.PPE)
# 0.07617254797045003 var_fre3.SUM(status.spread2)
# 0.2466556309072848 var_fre3.SUM(status.var_amp1)
# 0.25780108710882976 var_fre3.SUM(status.var_amp2)
# 0.23568296197306343 var_fre3.SUM(status.var_amp3)
# 0.24407680934744663 var_fre3.SUM(status.var_amp4)
# 0.26101583135303774 var_fre3.SUM(status.var_amp5)
# 0.23567761111855196 var_fre3.SUM(status.var_amp6)
# 0.20619846630635283 var_fre3.SUM(status.var_fre1)
# 0.2482934491406273 var_fre3.SUM(status.var_fre2)
# 0.2182074433654498 var_fre3.SUM(status.var_fre4)
# 0.22457572633261264 var_fre3.SUM(status.var_fre5)
# 0.28646497637709717 var_fre4.MAX(status.D2)
# 0.15436384836651895 var_fre4.MAX(status.DFA)
# 0.20595726238869638 var_fre4.MAX(status.NHR)
# 0.486809395769531 var_fre4.MAX(status.PPE)
# 0.22638931418069436 var_fre4.MAX(status.RPDE)
# 0.3890520734654648 var_fre4.MAX(status.spread2)
# 0.3726866750010876 var_fre4.MAX(status.var_amp1)
# 0.3572769115410025 var_fre4.MAX(status.var_amp2)
# 0.357878181914471 var_fre4.MAX(status.var_amp3)
# 0.3535538770174487 var_fre4.MAX(status.var_amp4)
# 0.3581351018244235 var_fre4.MAX(status.var_amp5)
# 0.3578724264009078 var_fre4.MAX(status.var_amp6)
# 0.27779353530895046 var_fre4.MAX(status.var_fre1)
# 0.3209574487547217 var_fre4.MAX(status.var_fre2)
# 0.2709232881918109 var_fre4.MAX(status.var_fre3)
# 0.27091446365006866 var_fre4.MAX(status.var_fre5)
# 0.3148552818758059 var_fre4.MEAN(status.D2)
# 0.19499185713794445 var_fre4.MEAN(status.DFA)
# 0.19774003211955232 var_fre4.MEAN(status.NHR)
# 0.4979894462712207 var_fre4.MEAN(status.PPE)
# 0.3199396189420305 var_fre4.MEAN(status.RPDE)
# 0.4384061400541196 var_fre4.MEAN(status.spread2)
# 0.3732246831824173 var_fre4.MEAN(status.var_amp1)
# 0.3575638485728977 var_fre4.MEAN(status.var_amp2)
# 0.35957053573618264 var_fre4.MEAN(status.var_amp3)
# 0.35563777213080866 var_fre4.MEAN(status.var_amp4)
# 0.3590503527430861 var_fre4.MEAN(status.var_amp5)
# 0.35956251049550714 var_fre4.MEAN(status.var_amp6)
# 0.2798995595641889 var_fre4.MEAN(status.var_fre1)
# 0.3281846086497205 var_fre4.MEAN(status.var_fre2)
# 0.2705351483889573 var_fre4.MEAN(status.var_fre3)
# 0.2705353092992597 var_fre4.MEAN(status.var_fre5)
# 0.31661591173061066 var_fre4.MIN(status.D2)
# 0.20589691405816826 var_fre4.MIN(status.DFA)
# 0.19152621705878808 var_fre4.MIN(status.NHR)
# 0.4838992607297021 var_fre4.MIN(status.PPE)
# 0.3667467264275047 var_fre4.MIN(status.RPDE)
# 0.43899673156427854 var_fre4.MIN(status.spread2)
# 0.3627834511248159 var_fre4.MIN(status.var_amp1)
# 0.34944938888318683 var_fre4.MIN(status.var_amp2)
# 0.3517863353692482 var_fre4.MIN(status.var_amp3)
# 0.3483392764943504 var_fre4.MIN(status.var_amp4)
# 0.34899731416857777 var_fre4.MIN(status.var_amp5)
# 0.351772115050763 var_fre4.MIN(status.var_amp6)
# 0.2809142914609093 var_fre4.MIN(status.var_fre1)
# 0.33169289257859447 var_fre4.MIN(status.var_fre2)
# 0.2702546466918181 var_fre4.MIN(status.var_fre3)
# 0.27023439097759494 var_fre4.MIN(status.var_fre5)
# 0.20568395688028643 var_fre4.SUM(status.NHR)
# 0.2706088542531817 var_fre4.SUM(status.PPE)
# 0.17441658204029908 var_fre4.SUM(status.spread2)
# 0.288967716066648 var_fre4.SUM(status.var_amp1)
# 0.2958751240588939 var_fre4.SUM(status.var_amp2)
# 0.2778964798858951 var_fre4.SUM(status.var_amp3)
# 0.28434877572257705 var_fre4.SUM(status.var_amp4)
# 0.29188423770683075 var_fre4.SUM(status.var_amp5)
# 0.27789004658455385 var_fre4.SUM(status.var_amp6)
# 0.23744341226861232 var_fre4.SUM(status.var_fre1)
# 0.26796342163375597 var_fre4.SUM(status.var_fre2)
# 0.24911283390706926 var_fre4.SUM(status.var_fre3)
# 0.2490738131021213 var_fre4.SUM(status.var_fre5)
# 0.31926632217038614 var_fre5.MAX(status.D2)
# 0.11404800612223583 var_fre5.MAX(status.DFA)
# 0.19740485464025218 var_fre5.MAX(status.NHR)
# 0.5065440320156865 var_fre5.MAX(status.PPE)
# 0.2903051083640328 var_fre5.MAX(status.RPDE)
# 0.42818626414278377 var_fre5.MAX(status.spread2)
# 0.368557870879162 var_fre5.MAX(status.var_amp1)
# 0.3546740983023478 var_fre5.MAX(status.var_amp2)
# 0.34828369646850393 var_fre5.MAX(status.var_amp3)
# 0.34909093509178646 var_fre5.MAX(status.var_amp4)
# 0.36591288294121627 var_fre5.MAX(status.var_amp5)
# 0.3482885466747557 var_fre5.MAX(status.var_amp6)
# 0.2725956657826936 var_fre5.MAX(status.var_fre1)
# 0.31901398682657395 var_fre5.MAX(status.var_fre2)
# 0.2666675565341965 var_fre5.MAX(status.var_fre3)
# 0.2829897832653764 var_fre5.MAX(status.var_fre4)
# 0.33938548548650804 var_fre5.MEAN(status.D2)
# 0.16707108962554876 var_fre5.MEAN(status.DFA)
# 0.20102462732749934 var_fre5.MEAN(status.NHR)
# 0.5227428887555274 var_fre5.MEAN(status.PPE)
# 0.3489047855880023 var_fre5.MEAN(status.RPDE)
# 0.45655901813613964 var_fre5.MEAN(status.spread2)
# 0.36297390395560214 var_fre5.MEAN(status.var_amp1)
# 0.34764142163016803 var_fre5.MEAN(status.var_amp2)
# 0.34471593261898126 var_fre5.MEAN(status.var_amp3)
# 0.34571713430126433 var_fre5.MEAN(status.var_amp4)
# 0.36085715457704626 var_fre5.MEAN(status.var_amp5)
# 0.34470854458183636 var_fre5.MEAN(status.var_amp6)
# 0.27806230229942613 var_fre5.MEAN(status.var_fre1)
# 0.3331580120808547 var_fre5.MEAN(status.var_fre2)
# 0.2666675565341965 var_fre5.MEAN(status.var_fre3)
# 0.28613728505145475 var_fre5.MEAN(status.var_fre4)
# 0.34218945929484995 var_fre5.MIN(status.D2)
# 0.21022586236932367 var_fre5.MIN(status.DFA)
# 0.20416975280310776 var_fre5.MIN(status.NHR)
# 0.5242286171780144 var_fre5.MIN(status.PPE)
# 0.3653342550075991 var_fre5.MIN(status.RPDE)
# 0.44955611343865604 var_fre5.MIN(status.spread2)
# 0.3488778176522695 var_fre5.MIN(status.var_amp1)
# 0.3346976934273326 var_fre5.MIN(status.var_amp2)
# 0.3281480214580028 var_fre5.MIN(status.var_amp3)
# 0.33490832495738665 var_fre5.MIN(status.var_amp4)
# 0.3515869370247281 var_fre5.MIN(status.var_amp5)
# 0.3281303961068805 var_fre5.MIN(status.var_amp6)
# 0.2809373190171332 var_fre5.MIN(status.var_fre1)
# 0.3467185310307641 var_fre5.MIN(status.var_fre2)
# 0.2666675565341965 var_fre5.MIN(status.var_fre3)
# 0.2892197676737988 var_fre5.MIN(status.var_fre4)
# 0.056899201486236874 var_fre5.SUM(status.D2)
# 0.196180882353558 var_fre5.SUM(status.NHR)
# 0.3676719792327703 var_fre5.SUM(status.PPE)
# 0.10047052631894864 var_fre5.SUM(status.RPDE)
# 0.2898890454611493 var_fre5.SUM(status.spread2)
# 0.3018191807771141 var_fre5.SUM(status.var_amp1)
# 0.3015935504295898 var_fre5.SUM(status.var_amp2)
# 0.2833177868879704 var_fre5.SUM(status.var_amp3)
# 0.29231765206877863 var_fre5.SUM(status.var_amp4)
# 0.31424259136436783 var_fre5.SUM(status.var_amp5)
# 0.283317129394358 var_fre5.SUM(status.var_amp6)
# 0.23842528963860016 var_fre5.SUM(status.var_fre1)
# 0.2907179156099578 var_fre5.SUM(status.var_fre2)
# 0.24109790064778824 var_fre5.SUM(status.var_fre3)
# 0.24709150190211204 var_fre5.SUM(status.var_fre4)
# 0.3299931673348829 var_amp1.MAX(status.D2)
# 0.21005432036287847 var_amp1.MAX(status.DFA)
# 0.18748774671424964 var_amp1.MAX(status.NHR)
# 0.5020470572379738 var_amp1.MAX(status.PPE)
# 0.2733176350840985 var_amp1.MAX(status.RPDE)
# 0.4003256627003837 var_amp1.MAX(status.spread2)
# 0.3505518218118428 var_amp1.MAX(status.var_amp2)
# 0.34957875397015953 var_amp1.MAX(status.var_amp3)
# 0.35317032137530335 var_amp1.MAX(status.var_amp4)
# 0.3597414390718708 var_amp1.MAX(status.var_amp5)
# 0.3495737122156197 var_amp1.MAX(status.var_amp6)
# 0.2693712537780022 var_amp1.MAX(status.var_fre1)
# 0.32753411869615257 var_amp1.MAX(status.var_fre2)
# 0.2640529800589332 var_amp1.MAX(status.var_fre3)
# 0.2835967191793323 var_amp1.MAX(status.var_fre4)
# 0.26401143925164733 var_amp1.MAX(status.var_fre5)
# 0.34141180924640047 var_amp1.MEAN(status.D2)
# 0.23107494597703232 var_amp1.MEAN(status.DFA)
# 0.18666287012741847 var_amp1.MEAN(status.NHR)
# 0.5105376175697118 var_amp1.MEAN(status.PPE)
# 0.2851400078073107 var_amp1.MEAN(status.RPDE)
# 0.42723463033172704 var_amp1.MEAN(status.spread2)
# 0.35020696550486163 var_amp1.MEAN(status.var_amp2)
# 0.34952391666311233 var_amp1.MEAN(status.var_amp3)
# 0.352104228128608 var_amp1.MEAN(status.var_amp4)
# 0.3605551106986523 var_amp1.MEAN(status.var_amp5)
# 0.34952131428237604 var_amp1.MEAN(status.var_amp6)
# 0.27104375489624655 var_amp1.MEAN(status.var_fre1)
# 0.3292463651955524 var_amp1.MEAN(status.var_fre2)
# 0.2625764885384441 var_amp1.MEAN(status.var_fre3)
# 0.2829273875743307 var_amp1.MEAN(status.var_fre4)
# 0.2625419283064621 var_amp1.MEAN(status.var_fre5)
# 0.3401095467682758 var_amp1.MIN(status.D2)
# 0.23209090219543646 var_amp1.MIN(status.DFA)
# 0.18559641680439481 var_amp1.MIN(status.NHR)
# 0.5103959766364017 var_amp1.MIN(status.PPE)
# 0.2921643925567274 var_amp1.MIN(status.RPDE)
# 0.4336215257501895 var_amp1.MIN(status.spread2)
# 0.3498035543984494 var_amp1.MIN(status.var_amp2)
# 0.3494318583904579 var_amp1.MIN(status.var_amp3)
# 0.350978389290858 var_amp1.MIN(status.var_amp4)
# 0.36126020772451045 var_amp1.MIN(status.var_amp5)
# 0.349431484080551 var_amp1.MIN(status.var_amp6)
# 0.2723094027488851 var_amp1.MIN(status.var_fre1)
# 0.32926524781219985 var_amp1.MIN(status.var_fre2)
# 0.2607099401875171 var_amp1.MIN(status.var_fre3)
# 0.281642665262478 var_amp1.MIN(status.var_fre4)
# 0.26068178749642107 var_amp1.MIN(status.var_fre5)
# 0.16682870268081168 var_amp1.SUM(status.D2)
# 0.1898989351888795 var_amp1.SUM(status.NHR)
# 0.4242201546156467 var_amp1.SUM(status.PPE)
# 0.1582510677523827 var_amp1.SUM(status.RPDE)
# 0.32104045452094004 var_amp1.SUM(status.spread2)
# 0.3469936130382848 var_amp1.SUM(status.var_amp2)
# 0.3433813545351579 var_amp1.SUM(status.var_amp3)
# 0.34842974524687353 var_amp1.SUM(status.var_amp4)
# 0.35596426537718046 var_amp1.SUM(status.var_amp5)
# 0.34337068691881 var_amp1.SUM(status.var_amp6)
# 0.26837613413988487 var_amp1.SUM(status.var_fre1)
# 0.32361848187621456 var_amp1.SUM(status.var_fre2)
# 0.26274230210537247 var_amp1.SUM(status.var_fre3)
# 0.2794806963143139 var_amp1.SUM(status.var_fre4)
# 0.26271134686862535 var_amp1.SUM(status.var_fre5)
# 0.20341129364355068 var_amp2.MAX(status.D2)
# 0.08217543256811857 var_amp2.MAX(status.DFA)
# 0.18912730100953185 var_amp2.MAX(status.NHR)
# 0.37622371958391 var_amp2.MAX(status.PPE)
# 0.21095206798968932 var_amp2.MAX(status.RPDE)
# 0.21121152486650344 var_amp2.MAX(status.spread2)
# 0.3656542464030774 var_amp2.MAX(status.var_amp1)
# 0.3509106496075384 var_amp2.MAX(status.var_amp3)
# 0.34243866851795896 var_amp2.MAX(status.var_amp4)
# 0.34244623232222504 var_amp2.MAX(status.var_amp5)
# 0.35090052168364877 var_amp2.MAX(status.var_amp6)
# 0.2564158754578418 var_amp2.MAX(status.var_fre1)
# 0.27543536406160124 var_amp2.MAX(status.var_fre2)
# 0.24869538202300767 var_amp2.MAX(status.var_fre3)
# 0.26422374861759945 var_amp2.MAX(status.var_fre4)
# 0.248585603359208 var_amp2.MAX(status.var_fre5)
# 0.3073919208897093 var_amp2.MEAN(status.D2)
# 0.21475145886488975 var_amp2.MEAN(status.DFA)
# 0.1968218721815611 var_amp2.MEAN(status.NHR)
# 0.4574494097732577 var_amp2.MEAN(status.PPE)
# 0.30808911862746685 var_amp2.MEAN(status.RPDE)
# 0.36757097024856566 var_amp2.MEAN(status.spread2)
# 0.365188281372685 var_amp2.MEAN(status.var_amp1)
# 0.3526882770765922 var_amp2.MEAN(status.var_amp3)
# 0.3486007943617149 var_amp2.MEAN(status.var_amp4)
# 0.3508321835480979 var_amp2.MEAN(status.var_amp5)
# 0.352675331625858 var_amp2.MEAN(status.var_amp6)
# 0.2681766342627394 var_amp2.MEAN(status.var_fre1)
# 0.3078152400462829 var_amp2.MEAN(status.var_fre2)
# 0.25950908504737835 var_amp2.MEAN(status.var_fre3)
# 0.27829211152466676 var_amp2.MEAN(status.var_fre4)
# 0.25942801217219547 var_amp2.MEAN(status.var_fre5)
# 0.3561557346098598 var_amp2.MIN(status.D2)
# 0.2900743883338311 var_amp2.MIN(status.DFA)
# 0.19713950975374353 var_amp2.MIN(status.NHR)
# 0.47973654451360576 var_amp2.MIN(status.PPE)
# 0.36295466419161876 var_amp2.MIN(status.RPDE)
# 0.43477759862106047 var_amp2.MIN(status.spread2)
# 0.36445801222201685 var_amp2.MIN(status.var_amp1)
# 0.3551209010018442 var_amp2.MIN(status.var_amp3)
# 0.35322633064038433 var_amp2.MIN(status.var_amp4)
# 0.3545821485320435 var_amp2.MIN(status.var_amp5)
# 0.35510634539282193 var_amp2.MIN(status.var_amp6)
# 0.27866293440526213 var_amp2.MIN(status.var_fre1)
# 0.32651006743316807 var_amp2.MIN(status.var_fre2)
# 0.2654759645239759 var_amp2.MIN(status.var_fre3)
# 0.28532001262362444 var_amp2.MIN(status.var_fre4)
# 0.26542903795250417 var_amp2.MIN(status.var_fre5)
# 0.15400041630471387 var_amp2.SUM(status.NHR)
# 0.12373416414437514 var_amp2.SUM(status.var_amp1)
# 0.11627335856127878 var_amp2.SUM(status.var_amp3)
# 0.12644742741319967 var_amp2.SUM(status.var_amp4)
# 0.13806182385523966 var_amp2.SUM(status.var_amp5)
# 0.11626086132525201 var_amp2.SUM(status.var_amp6)
# 0.06478484484001762 var_amp2.SUM(status.var_fre1)
# 0.10776956324777635 var_amp2.SUM(status.var_fre2)
# 0.09926429196647477 var_amp2.SUM(status.var_fre3)
# 0.08745244476951736 var_amp2.SUM(status.var_fre4)
# 0.09911045733939619 var_amp2.SUM(status.var_fre5)
# 0.12851699170375924 var_amp3.COUNT(status)
# 0.34868937548713097 var_amp3.MAX(status.D2)
# 0.2631819997263391 var_amp3.MAX(status.DFA)
# 0.19419705717017244 var_amp3.MAX(status.NHR)
# 0.5373934181123111 var_amp3.MAX(status.PPE)
# 0.3187678201004103 var_amp3.MAX(status.RPDE)
# 0.4631946160880488 var_amp3.MAX(status.spread2)
# 0.3703325027252727 var_amp3.MAX(status.var_amp1)
# 0.35437200940303737 var_amp3.MAX(status.var_amp2)
# 0.3547222046986849 var_amp3.MAX(status.var_amp4)
# 0.368570065437436 var_amp3.MAX(status.var_amp5)
# 0.34761597601290833 var_amp3.MAX(status.var_amp6)
# 0.285264560557242 var_amp3.MAX(status.var_fre1)
# 0.34648365580310975 var_amp3.MAX(status.var_fre2)
# 0.27336752924810753 var_amp3.MAX(status.var_fre3)
# 0.2937271505153769 var_amp3.MAX(status.var_fre4)
# 0.2733598903474417 var_amp3.MAX(status.var_fre5)
# 0.3326781496946067 var_amp3.MEAN(status.D2)
# 0.24291662753456778 var_amp3.MEAN(status.DFA)
# 0.18885163018501067 var_amp3.MEAN(status.NHR)
# 0.5324788176838808 var_amp3.MEAN(status.PPE)
# 0.30830197514370855 var_amp3.MEAN(status.RPDE)
# 0.4523941181042045 var_amp3.MEAN(status.spread2)
# 0.366613592796595 var_amp3.MEAN(status.var_amp1)
# 0.349795125033313 var_amp3.MEAN(status.var_amp2)
# 0.35112604319287355 var_amp3.MEAN(status.var_amp4)
# 0.36251116721891635 var_amp3.MEAN(status.var_amp5)
# 0.3476122734238823 var_amp3.MEAN(status.var_amp6)
# 0.27744536058653624 var_amp3.MEAN(status.var_fre1)
# 0.33768282904682195 var_amp3.MEAN(status.var_fre2)
# 0.2665862498040509 var_amp3.MEAN(status.var_fre3)
# 0.2879102667942038 var_amp3.MEAN(status.var_fre4)
# 0.2665582019549762 var_amp3.MEAN(status.var_fre5)
# 0.30956001341933437 var_amp3.MIN(status.D2)
# 0.21172838943706582 var_amp3.MIN(status.DFA)
# 0.18307257646294478 var_amp3.MIN(status.NHR)
# 0.5157674530757157 var_amp3.MIN(status.PPE)
# 0.2894489996475074 var_amp3.MIN(status.RPDE)
# 0.42149374741905526 var_amp3.MIN(status.spread2)
# 0.3624288759271415 var_amp3.MIN(status.var_amp1)
# 0.3445599318141643 var_amp3.MIN(status.var_amp2)
# 0.34729266730876485 var_amp3.MIN(status.var_amp4)
# 0.35456082021742685 var_amp3.MIN(status.var_amp5)
# 0.3476085701467287 var_amp3.MIN(status.var_amp6)
# 0.26862043813857217 var_amp3.MIN(status.var_fre1)
# 0.3268511032919246 var_amp3.MIN(status.var_fre2)
# 0.2589141217057085 var_amp3.MIN(status.var_fre3)
# 0.28131779926406336 var_amp3.MIN(status.var_fre4)
# 0.2588653631853887 var_amp3.MIN(status.var_fre5)
# 0.29100899757455906 var_amp3.SUM(status.D2)
# 0.18221994510704276 var_amp3.SUM(status.DFA)
# 0.20435739079231313 var_amp3.SUM(status.NHR)
# 0.5009671907351105 var_amp3.SUM(status.PPE)
# 0.28722879904932297 var_amp3.SUM(status.RPDE)
# 0.40702463948937795 var_amp3.SUM(status.spread2)
# 0.4093491612770232 var_amp3.SUM(status.var_amp1)
# 0.3896238581200315 var_amp3.SUM(status.var_amp2)
# 0.3936512217391752 var_amp3.SUM(status.var_amp4)
# 0.39911315545632936 var_amp3.SUM(status.var_amp5)
# 0.39192868621145743 var_amp3.SUM(status.var_amp6)
# 0.31590316972577914 var_amp3.SUM(status.var_fre1)
# 0.3704282736465778 var_amp3.SUM(status.var_fre2)
# 0.2996428302593385 var_amp3.SUM(status.var_fre3)
# 0.3251216497276658 var_amp3.SUM(status.var_fre4)
# 0.2996266728829128 var_amp3.SUM(status.var_fre5)
# 0.3016681124384759 var_amp4.MAX(status.D2)
# 0.1774813883769796 var_amp4.MAX(status.DFA)
# 0.1870912564017464 var_amp4.MAX(status.NHR)
# 0.5098383257021931 var_amp4.MAX(status.PPE)
# 0.2894988403447889 var_amp4.MAX(status.RPDE)
# 0.4069667549744666 var_amp4.MAX(status.spread2)
# 0.3636346347879557 var_amp4.MAX(status.var_amp1)
# 0.3463058785952867 var_amp4.MAX(status.var_amp2)
# 0.3442758928357742 var_amp4.MAX(status.var_amp3)
# 0.35937133445012426 var_amp4.MAX(status.var_amp5)
# 0.344263329576674 var_amp4.MAX(status.var_amp6)
# 0.27208080427612974 var_amp4.MAX(status.var_fre1)
# 0.32879916406694554 var_amp4.MAX(status.var_fre2)
# 0.2613320133986244 var_amp4.MAX(status.var_fre3)
# 0.283641844478129 var_amp4.MAX(status.var_fre4)
# 0.26129134086470474 var_amp4.MAX(status.var_fre5)
# 0.32837910549086174 var_amp4.MEAN(status.D2)
# 0.21225396712159744 var_amp4.MEAN(status.DFA)
# 0.1890273884770831 var_amp4.MEAN(status.NHR)
# 0.5201790056229914 var_amp4.MEAN(status.PPE)
# 0.32979141126179695 var_amp4.MEAN(status.RPDE)
# 0.43426606607363094 var_amp4.MEAN(status.spread2)
# 0.366431235389534 var_amp4.MEAN(status.var_amp1)
# 0.34881541515520437 var_amp4.MEAN(status.var_amp2)
# 0.34702005687331694 var_amp4.MEAN(status.var_amp3)
# 0.36343973179337075 var_amp4.MEAN(status.var_amp5)
# 0.34701550845384344 var_amp4.MEAN(status.var_amp6)
# 0.27723825879741637 var_amp4.MEAN(status.var_fre1)
# 0.33930279239369404 var_amp4.MEAN(status.var_fre2)
# 0.26522478623215456 var_amp4.MEAN(status.var_fre3)
# 0.2878664239538249 var_amp4.MEAN(status.var_fre4)
# 0.26519654312808505 var_amp4.MEAN(status.var_fre5)
# 0.34725165817848613 var_amp4.MIN(status.D2)
# 0.24138397174252146 var_amp4.MIN(status.DFA)
# 0.19090866638366463 var_amp4.MIN(status.NHR)
# 0.5257096995085633 var_amp4.MIN(status.PPE)
# 0.3562619466548225 var_amp4.MIN(status.RPDE)
# 0.44922983224316 var_amp4.MIN(status.spread2)
# 0.3691250638790631 var_amp4.MIN(status.var_amp1)
# 0.351225465966671 var_amp4.MIN(status.var_amp2)
# 0.34964849527312836 var_amp4.MIN(status.var_amp3)
# 0.367276894510259 var_amp4.MIN(status.var_amp5)
# 0.3496516288564549 var_amp4.MIN(status.var_amp6)
# 0.28205099309516907 var_amp4.MIN(status.var_fre1)
# 0.3484630285767555 var_amp4.MIN(status.var_fre2)
# 0.2688173740977778 var_amp4.MIN(status.var_fre3)
# 0.2917150018678123 var_amp4.MIN(status.var_fre4)
# 0.2688016612582339 var_amp4.MIN(status.var_fre5)
# 0.1806897562136942 var_amp4.SUM(status.NHR)
# 0.4320852546037403 var_amp4.SUM(status.PPE)
# 0.08951580363679199 var_amp4.SUM(status.RPDE)
# 0.28140166844490466 var_amp4.SUM(status.spread2)
# 0.3203135061543093 var_amp4.SUM(status.var_amp1)
# 0.3079511993653601 var_amp4.SUM(status.var_amp2)
# 0.29972262192107113 var_amp4.SUM(status.var_amp3)
# 0.323597739300768 var_amp4.SUM(status.var_amp5)
# 0.299718613927954 var_amp4.SUM(status.var_amp6)
# 0.23730914197894448 var_amp4.SUM(status.var_fre1)
# 0.3009928268648504 var_amp4.SUM(status.var_fre2)
# 0.2359059471587989 var_amp4.SUM(status.var_fre3)
# 0.2525662928567096 var_amp4.SUM(status.var_fre4)
# 0.23588589620443629 var_amp4.SUM(status.var_fre5)
# 0.32023123120449676 var_amp5.MAX(status.D2)
# 0.19530665521986132 var_amp5.MAX(status.DFA)
# 0.18981102543524225 var_amp5.MAX(status.NHR)
# 0.5212983842807579 var_amp5.MAX(status.PPE)
# 0.30955137274994204 var_amp5.MAX(status.RPDE)
# 0.4469815443924573 var_amp5.MAX(status.spread2)
# 0.3673101641322282 var_amp5.MAX(status.var_amp1)
# 0.3512956137539399 var_amp5.MAX(status.var_amp2)
# 0.34679342370479027 var_amp5.MAX(status.var_amp3)
# 0.3515725203911599 var_amp5.MAX(status.var_amp4)
# 0.3467895803596167 var_amp5.MAX(status.var_amp6)
# 0.2820270020120681 var_amp5.MAX(status.var_fre1)
# 0.3422310226145658 var_amp5.MAX(status.var_fre2)
# 0.2709494618446655 var_amp5.MAX(status.var_fre3)
# 0.29314796529383236 var_amp5.MAX(status.var_fre4)
# 0.27091268472307417 var_amp5.MAX(status.var_fre5)
# 0.33428243202162633 var_amp5.MEAN(status.D2)
# 0.22863101376467543 var_amp5.MEAN(status.DFA)
# 0.19103792774721484 var_amp5.MEAN(status.NHR)
# 0.5296634191398025 var_amp5.MEAN(status.PPE)
# 0.32154553974018696 var_amp5.MEAN(status.RPDE)
# 0.4553609969981169 var_amp5.MEAN(status.spread2)
# 0.3682819289273715 var_amp5.MEAN(status.var_amp1)
# 0.35176325526688873 var_amp5.MEAN(status.var_amp2)
# 0.34842791386077265 var_amp5.MEAN(status.var_amp3)
# 0.3526213951106114 var_amp5.MEAN(status.var_amp4)
# 0.3484208391761893 var_amp5.MEAN(status.var_amp6)
# 0.2807569308514381 var_amp5.MEAN(status.var_fre1)
# 0.34548755670832226 var_amp5.MEAN(status.var_fre2)
# 0.26899876261794126 var_amp5.MEAN(status.var_fre3)
# 0.2913018073162679 var_amp5.MEAN(status.var_fre4)
# 0.26896283602282833 var_amp5.MEAN(status.var_fre5)
# 0.3456967599232667 var_amp5.MIN(status.D2)
# 0.2510035066668843 var_amp5.MIN(status.DFA)
# 0.19221819762410425 var_amp5.MIN(status.NHR)
# 0.5336901888220836 var_amp5.MIN(status.PPE)
# 0.32786150520213225 var_amp5.MIN(status.RPDE)
# 0.45803723143157143 var_amp5.MIN(status.spread2)
# 0.36876865798953246 var_amp5.MIN(status.var_amp1)
# 0.3516450614878447 var_amp5.MIN(status.var_amp2)
# 0.3495191619836865 var_amp5.MIN(status.var_amp3)
# 0.3521611641184309 var_amp5.MIN(status.var_amp4)
# 0.3495096775638764 var_amp5.MIN(status.var_amp6)
# 0.27859578327493195 var_amp5.MIN(status.var_fre1)
# 0.34546357596765165 var_amp5.MIN(status.var_fre2)
# 0.26638760030968484 var_amp5.MIN(status.var_fre3)
# 0.2875152049837851 var_amp5.MIN(status.var_fre4)
# 0.266354493869104 var_amp5.MIN(status.var_fre5)
# 0.1167984541457601 var_amp5.SUM(status.D2)
# 0.18951956070904707 var_amp5.SUM(status.NHR)
# 0.4599348294897047 var_amp5.SUM(status.PPE)
# 0.18936093113055058 var_amp5.SUM(status.RPDE)
# 0.3909924322579501 var_amp5.SUM(status.spread2)
# 0.34160157302438804 var_amp5.SUM(status.var_amp1)
# 0.3310179822623024 var_amp5.SUM(status.var_amp2)
# 0.3222678785547234 var_amp5.SUM(status.var_amp3)
# 0.32463343623777535 var_amp5.SUM(status.var_amp4)
# 0.32226379960360974 var_amp5.SUM(status.var_amp6)
# 0.2674878127375659 var_amp5.SUM(status.var_fre1)
# 0.33316866979536547 var_amp5.SUM(status.var_fre2)
# 0.25839494699479676 var_amp5.SUM(status.var_fre3)
# 0.2759775886223246 var_amp5.SUM(status.var_fre4)
# 0.2583467677902479 var_amp5.SUM(status.var_fre5)
# 0.14632786278045254 var_amp6.COUNT(status)
# 0.3555340558707285 var_amp6.MAX(status.D2)
# 0.2486027914576023 var_amp6.MAX(status.DFA)
# 0.1937896027901983 var_amp6.MAX(status.NHR)
# 0.54365708489261 var_amp6.MAX(status.PPE)
# 0.3170345199159379 var_amp6.MAX(status.RPDE)
# 0.47823187693395924 var_amp6.MAX(status.spread2)
# 0.3706760014835976 var_amp6.MAX(status.var_amp1)
# 0.35410099722895444 var_amp6.MAX(status.var_amp2)
# 0.34761696522403307 var_amp6.MAX(status.var_amp3)
# 0.354312204235167 var_amp6.MAX(status.var_amp4)
# 0.3703423776939652 var_amp6.MAX(status.var_amp5)
# 0.28529953405480396 var_amp6.MAX(status.var_fre1)
# 0.3455524497513853 var_amp6.MAX(status.var_fre2)
# 0.2733007122495499 var_amp6.MAX(status.var_fre3)
# 0.2947391505745879 var_amp6.MAX(status.var_fre4)
# 0.27327770516141253 var_amp6.MAX(status.var_fre5)
# 0.3423138965467208 var_amp6.MEAN(status.D2)
# 0.23351474326006 var_amp6.MEAN(status.DFA)
# 0.18960508419091238 var_amp6.MEAN(status.NHR)
# 0.5348715322650291 var_amp6.MEAN(status.PPE)
# 0.3091466884609663 var_amp6.MEAN(status.RPDE)
# 0.45972507587003714 var_amp6.MEAN(status.spread2)
# 0.367637811010292 var_amp6.MEAN(status.var_amp1)
# 0.35093115413291737 var_amp6.MEAN(status.var_amp2)
# 0.34761696522403307 var_amp6.MEAN(status.var_amp3)
# 0.35126884700062155 var_amp6.MEAN(status.var_amp4)
# 0.36509010754948845 var_amp6.MEAN(status.var_amp5)
# 0.27870192415096234 var_amp6.MEAN(status.var_fre1)
# 0.33948392765293867 var_amp6.MEAN(status.var_fre2)
# 0.26712776080631395 var_amp6.MEAN(status.var_fre3)
# 0.28908837103323404 var_amp6.MEAN(status.var_fre4)
# 0.26710635075992867 var_amp6.MEAN(status.var_fre5)
# 0.32537238339985197 var_amp6.MIN(status.D2)
# 0.21520395307253384 var_amp6.MIN(status.DFA)
# 0.1850787008603719 var_amp6.MIN(status.NHR)
# 0.5186769968552286 var_amp6.MIN(status.PPE)
# 0.30019649378422025 var_amp6.MIN(status.RPDE)
# 0.4324309674601739 var_amp6.MIN(status.spread2)
# 0.3641977943133666 var_amp6.MIN(status.var_amp1)
# 0.3473071802886871 var_amp6.MIN(status.var_amp2)
# 0.34761696522403307 var_amp6.MIN(status.var_amp3)
# 0.3480000285694636 var_amp6.MIN(status.var_amp4)
# 0.358328279519541 var_amp6.MIN(status.var_amp5)
# 0.2711909592584987 var_amp6.MIN(status.var_fre1)
# 0.3317861497409758 var_amp6.MIN(status.var_fre2)
# 0.2600698391495285 var_amp6.MIN(status.var_fre3)
# 0.28269933370910216 var_amp6.MIN(status.var_fre4)
# 0.26004984474801174 var_amp6.MIN(status.var_fre5)
# 0.3216922111496104 var_amp6.SUM(status.D2)
# 0.21361034109764168 var_amp6.SUM(status.DFA)
# 0.20186286049370508 var_amp6.SUM(status.NHR)
# 0.5259215686989426 var_amp6.SUM(status.PPE)
# 0.29587287970275766 var_amp6.SUM(status.RPDE)
# 0.46040207416031753 var_amp6.SUM(status.spread2)
# 0.39838194838101765 var_amp6.SUM(status.var_amp1)
# 0.3796160897301824 var_amp6.SUM(status.var_amp2)
# 0.37856285752632507 var_amp6.SUM(status.var_amp3)
# 0.3822978016963418 var_amp6.SUM(status.var_amp4)
# 0.3927514117610419 var_amp6.SUM(status.var_amp5)
# 0.3057605922090851 var_amp6.SUM(status.var_fre1)
# 0.3607877272124308 var_amp6.SUM(status.var_fre2)
# 0.2902259619935485 var_amp6.SUM(status.var_fre3)
# 0.3151792270583168 var_amp6.SUM(status.var_fre4)
# 0.29021559110215284 var_amp6.SUM(status.var_fre5)
# 0.27385521408683366 NHR.MAX(status.D2)
# 0.17522172326952526 NHR.MAX(status.DFA)
# 0.4614761249187379 NHR.MAX(status.PPE)
# 0.2968771200087872 NHR.MAX(status.RPDE)
# 0.39572106999818585 NHR.MAX(status.spread2)
# 0.35379959118061954 NHR.MAX(status.var_amp1)
# 0.33885785332338664 NHR.MAX(status.var_amp2)
# 0.33402413000138353 NHR.MAX(status.var_amp3)
# 0.3371389075715057 NHR.MAX(status.var_amp4)
# 0.349162180945556 NHR.MAX(status.var_amp5)
# 0.3340219674711023 NHR.MAX(status.var_amp6)
# 0.2721217463055162 NHR.MAX(status.var_fre1)
# 0.3282333191219258 NHR.MAX(status.var_fre2)
# 0.25802396723054255 NHR.MAX(status.var_fre3)
# 0.27923788902538393 NHR.MAX(status.var_fre4)
# 0.25799608839336413 NHR.MAX(status.var_fre5)
# 0.3087540470812806 NHR.MEAN(status.D2)
# 0.2014885769123337 NHR.MEAN(status.DFA)
# 0.488140854310315 NHR.MEAN(status.PPE)
# 0.30763139877333884 NHR.MEAN(status.RPDE)
# 0.4266541187066798 NHR.MEAN(status.spread2)
# 0.35934996571767686 NHR.MEAN(status.var_amp1)
# 0.343800020800085 NHR.MEAN(status.var_amp2)
# 0.3402482619404812 NHR.MEAN(status.var_amp3)
# 0.34232161461287514 NHR.MEAN(status.var_amp4)
# 0.35435851284373426 NHR.MEAN(status.var_amp5)
# 0.34024795003560826 NHR.MEAN(status.var_amp6)
# 0.2754475761951606 NHR.MEAN(status.var_fre1)
# 0.33124832330235804 NHR.MEAN(status.var_fre2)
# 0.2619021223300738 NHR.MEAN(status.var_fre3)
# 0.28130736350512037 NHR.MEAN(status.var_fre4)
# 0.2618677234230991 NHR.MEAN(status.var_fre5)
# 0.3246810976523492 NHR.MIN(status.D2)
# 0.209761717448497 NHR.MIN(status.DFA)
# 0.4977588778392939 NHR.MIN(status.PPE)
# 0.3139202285383474 NHR.MIN(status.RPDE)
# 0.43871504261809546 NHR.MIN(status.spread2)
# 0.36323934083634807 NHR.MIN(status.var_amp1)
# 0.34739051251757996 NHR.MIN(status.var_amp2)
# 0.3448650141452573 NHR.MIN(status.var_amp3)
# 0.34557351557794036 NHR.MIN(status.var_amp4)
# 0.35794224691554255 NHR.MIN(status.var_amp5)
# 0.3448654523019789 NHR.MIN(status.var_amp6)
# 0.27785524704000086 NHR.MIN(status.var_fre1)
# 0.3320500333973285 NHR.MIN(status.var_fre2)
# 0.26491764570261755 NHR.MIN(status.var_fre3)
# 0.281716781905249 NHR.MIN(status.var_fre4)
# 0.264875968377108 NHR.MIN(status.var_fre5)
# 0.3724142347268951 NHR.SUM(status.PPE)
# 0.053089433323810865 NHR.SUM(status.RPDE)
# 0.25471495222889223 NHR.SUM(status.spread2)
# 0.3032678633804607 NHR.SUM(status.var_amp1)
# 0.2947629489997718 NHR.SUM(status.var_amp2)
# 0.2802712851782215 NHR.SUM(status.var_amp3)
# 0.29147793804118666 NHR.SUM(status.var_amp4)
# 0.3117190580448578 NHR.SUM(status.var_amp5)
# 0.2802528352888122 NHR.SUM(status.var_amp6)
# 0.23699075456202573 NHR.SUM(status.var_fre1)
# 0.3044281978890043 NHR.SUM(status.var_fre2)
# 0.23082175157749998 NHR.SUM(status.var_fre3)
# 0.24508876251118658 NHR.SUM(status.var_fre4)
# 0.23081864036751545 NHR.SUM(status.var_fre5)
# 0.34023150988036344 HNR.MAX(status.D2)
# 0.23173927276037898 HNR.MAX(status.DFA)
# 0.18942931888728265 HNR.MAX(status.NHR)
# 0.5310391538731206 HNR.MAX(status.PPE)
# 0.30856725130270324 HNR.MAX(status.RPDE)
# 0.4548421261086427 HNR.MAX(status.spread2)
# 0.3674298598935416 HNR.MAX(status.var_amp1)
# 0.3506969057174749 HNR.MAX(status.var_amp2)
# 0.34761696522403307 HNR.MAX(status.var_amp3)
# 0.3511484359380265 HNR.MAX(status.var_amp4)
# 0.36431573922311206 HNR.MAX(status.var_amp5)
# 0.3476083545379774 HNR.MAX(status.var_amp6)
# 0.2782195982792975 HNR.MAX(status.var_fre1)
# 0.3386530980793471 HNR.MAX(status.var_fre2)
# 0.2666675565341965 HNR.MAX(status.var_fre3)
# 0.2886983466906385 HNR.MAX(status.var_fre4)
# 0.2666460942115801 HNR.MAX(status.var_fre5)
# 0.34023150988036344 HNR.MEAN(status.D2)
# 0.23173927276037898 HNR.MEAN(status.DFA)
# 0.18942931888728265 HNR.MEAN(status.NHR)
# 0.5310391538731206 HNR.MEAN(status.PPE)
# 0.30856725130270324 HNR.MEAN(status.RPDE)
# 0.4548421261086427 HNR.MEAN(status.spread2)
# 0.3674298598935416 HNR.MEAN(status.var_amp1)
# 0.3506969057174749 HNR.MEAN(status.var_amp2)
# ...
# 0.2782195982792975 RPDE.MIN(status.var_fre1)
# 0.3386530980793471 RPDE.MIN(status.var_fre2)
# 0.2666675565341965 RPDE.MIN(status.var_fre3)
# 0.2886983466906385 RPDE.MIN(status.var_fre4)
# 0.2666460942115801 RPDE.MIN(status.var_fre5)
# 0.34023150988036344 RPDE.SUM(status.D2)
# 0.23173927276037898 RPDE.SUM(status.DFA)
# 0.18942931888728265 RPDE.SUM(status.NHR)
# 0.5310391538731206 RPDE.SUM(status.PPE)
# 0.4548421261086427 RPDE.SUM(status.spread2)
# 0.3674298598935416 RPDE.SUM(status.var_amp1)
# 0.3506969057174749 RPDE.SUM(status.var_amp2)
# 0.34761696522403307 RPDE.SUM(status.var_amp3)
# 0.3511484359380265 RPDE.SUM(status.var_amp4)
# 0.36431573922311206 RPDE.SUM(status.var_amp5)
# 0.3476083545379774 RPDE.SUM(status.var_amp6)
# 0.2782195982792975 RPDE.SUM(status.var_fre1)
# 0.3386530980793471 RPDE.SUM(status.var_fre2)
# 0.2666675565341965 RPDE.SUM(status.var_fre3)
# 0.2886983466906385 RPDE.SUM(status.var_fre4)
# 0.2666460942115801 RPDE.SUM(status.var_fre5)
# 0.34023150988036344 DFA.MAX(status.D2)
# 0.18942931888728265 DFA.MAX(status.NHR)
# 0.5310391538731206 DFA.MAX(status.PPE)
# 0.30856725130270324 DFA.MAX(status.RPDE)
# 0.4548421261086427 DFA.MAX(status.spread2)
# 0.3674298598935416 DFA.MAX(status.var_amp1)
# 0.3506969057174749 DFA.MAX(status.var_amp2)
# 0.34761696522403307 DFA.MAX(status.var_amp3)
# 0.3511484359380265 DFA.MAX(status.var_amp4)
# 0.36431573922311206 DFA.MAX(status.var_amp5)
# 0.3476083545379774 DFA.MAX(status.var_amp6)
# 0.2782195982792975 DFA.MAX(status.var_fre1)
# 0.3386530980793471 DFA.MAX(status.var_fre2)
# 0.2666675565341965 DFA.MAX(status.var_fre3)
# 0.2886983466906385 DFA.MAX(status.var_fre4)
# 0.2666460942115801 DFA.MAX(status.var_fre5)
# 0.34023150988036344 DFA.MEAN(status.D2)
# 0.18942931888728265 DFA.MEAN(status.NHR)
# 0.5310391538731206 DFA.MEAN(status.PPE)
# 0.30856725130270324 DFA.MEAN(status.RPDE)
# 0.4548421261086427 DFA.MEAN(status.spread2)
# 0.3674298598935416 DFA.MEAN(status.var_amp1)
# 0.3506969057174749 DFA.MEAN(status.var_amp2)
# 0.34761696522403307 DFA.MEAN(status.var_amp3)
# 0.3511484359380265 DFA.MEAN(status.var_amp4)
# 0.36431573922311206 DFA.MEAN(status.var_amp5)
# 0.3476083545379774 DFA.MEAN(status.var_amp6)
# 0.2782195982792975 DFA.MEAN(status.var_fre1)
# 0.3386530980793471 DFA.MEAN(status.var_fre2)
# 0.2666675565341965 DFA.MEAN(status.var_fre3)
# 0.2886983466906385 DFA.MEAN(status.var_fre4)
# 0.2666460942115801 DFA.MEAN(status.var_fre5)
# 0.34023150988036344 DFA.MIN(status.D2)
# 0.18942931888728265 DFA.MIN(status.NHR)
# 0.5310391538731206 DFA.MIN(status.PPE)
# 0.30856725130270324 DFA.MIN(status.RPDE)
# 0.4548421261086427 DFA.MIN(status.spread2)
# 0.3674298598935416 DFA.MIN(status.var_amp1)
# 0.3506969057174749 DFA.MIN(status.var_amp2)
# 0.34761696522403307 DFA.MIN(status.var_amp3)
# 0.3511484359380265 DFA.MIN(status.var_amp4)
# 0.36431573922311206 DFA.MIN(status.var_amp5)
# 0.3476083545379774 DFA.MIN(status.var_amp6)
# 0.2782195982792975 DFA.MIN(status.var_fre1)
# 0.3386530980793471 DFA.MIN(status.var_fre2)
# 0.2666675565341965 DFA.MIN(status.var_fre3)
# 0.2886983466906385 DFA.MIN(status.var_fre4)
# 0.2666460942115801 DFA.MIN(status.var_fre5)
# 0.34023150988036344 DFA.SUM(status.D2)
# 0.18942931888728265 DFA.SUM(status.NHR)
# 0.5310391538731206 DFA.SUM(status.PPE)
# 0.30856725130270324 DFA.SUM(status.RPDE)
# 0.4548421261086427 DFA.SUM(status.spread2)
# 0.3674298598935416 DFA.SUM(status.var_amp1)
# 0.3506969057174749 DFA.SUM(status.var_amp2)
# 0.34761696522403307 DFA.SUM(status.var_amp3)
# 0.3511484359380265 DFA.SUM(status.var_amp4)
# 0.36431573922311206 DFA.SUM(status.var_amp5)
# 0.3476083545379774 DFA.SUM(status.var_amp6)
# 0.2782195982792975 DFA.SUM(status.var_fre1)
# 0.3386530980793471 DFA.SUM(status.var_fre2)
# 0.2666675565341965 DFA.SUM(status.var_fre3)
# 0.2886983466906385 DFA.SUM(status.var_fre4)
# 0.2666460942115801 DFA.SUM(status.var_fre5)
# 0.34023150988036344 spread1.MAX(status.D2)
# 0.23173927276037898 spread1.MAX(status.DFA)
# 0.18942931888728265 spread1.MAX(status.NHR)
# 0.5310391538731206 spread1.MAX(status.PPE)
# 0.30856725130270324 spread1.MAX(status.RPDE)
# 0.4548421261086427 spread1.MAX(status.spread2)
# 0.3674298598935416 spread1.MAX(status.var_amp1)
# 0.3506969057174749 spread1.MAX(status.var_amp2)
# 0.34761696522403307 spread1.MAX(status.var_amp3)
# 0.3511484359380265 spread1.MAX(status.var_amp4)
# 0.36431573922311206 spread1.MAX(status.var_amp5)
# 0.3476083545379774 spread1.MAX(status.var_amp6)
# 0.2782195982792975 spread1.MAX(status.var_fre1)
# 0.3386530980793471 spread1.MAX(status.var_fre2)
# 0.2666675565341965 spread1.MAX(status.var_fre3)
# 0.2886983466906385 spread1.MAX(status.var_fre4)
# 0.2666460942115801 spread1.MAX(status.var_fre5)
# 0.34023150988036344 spread1.MEAN(status.D2)
# 0.23173927276037898 spread1.MEAN(status.DFA)
# 0.18942931888728265 spread1.MEAN(status.NHR)
# 0.5310391538731206 spread1.MEAN(status.PPE)
# 0.30856725130270324 spread1.MEAN(status.RPDE)
# 0.4548421261086427 spread1.MEAN(status.spread2)
# 0.3674298598935416 spread1.MEAN(status.var_amp1)
# 0.3506969057174749 spread1.MEAN(status.var_amp2)
# 0.34761696522403307 spread1.MEAN(status.var_amp3)
# 0.3511484359380265 spread1.MEAN(status.var_amp4)
# 0.36431573922311206 spread1.MEAN(status.var_amp5)
# 0.3476083545379774 spread1.MEAN(status.var_amp6)
# 0.2782195982792975 spread1.MEAN(status.var_fre1)
# 0.3386530980793471 spread1.MEAN(status.var_fre2)
# 0.2666675565341965 spread1.MEAN(status.var_fre3)
# 0.2886983466906385 spread1.MEAN(status.var_fre4)
# 0.2666460942115801 spread1.MEAN(status.var_fre5)
# 0.34023150988036344 spread1.MIN(status.D2)
# 0.23173927276037898 spread1.MIN(status.DFA)
# 0.18942931888728265 spread1.MIN(status.NHR)
# 0.5310391538731206 spread1.MIN(status.PPE)
# 0.30856725130270324 spread1.MIN(status.RPDE)
# 0.4548421261086427 spread1.MIN(status.spread2)
# 0.3674298598935416 spread1.MIN(status.var_amp1)
# 0.3506969057174749 spread1.MIN(status.var_amp2)
# 0.34761696522403307 spread1.MIN(status.var_amp3)
# 0.3511484359380265 spread1.MIN(status.var_amp4)
# 0.36431573922311206 spread1.MIN(status.var_amp5)
# 0.3476083545379774 spread1.MIN(status.var_amp6)
# 0.2782195982792975 spread1.MIN(status.var_fre1)
# 0.3386530980793471 spread1.MIN(status.var_fre2)
# 0.2666675565341965 spread1.MIN(status.var_fre3)
# 0.2886983466906385 spread1.MIN(status.var_fre4)
# 0.2666460942115801 spread1.MIN(status.var_fre5)
# 0.34023150988036344 spread1.SUM(status.D2)
# 0.23173927276037898 spread1.SUM(status.DFA)
# 0.18942931888728265 spread1.SUM(status.NHR)
# 0.5310391538731206 spread1.SUM(status.PPE)
# 0.30856725130270324 spread1.SUM(status.RPDE)
# 0.4548421261086427 spread1.SUM(status.spread2)
# 0.3674298598935416 spread1.SUM(status.var_amp1)
# 0.3506969057174749 spread1.SUM(status.var_amp2)
# 0.34761696522403307 spread1.SUM(status.var_amp3)
# 0.3511484359380265 spread1.SUM(status.var_amp4)
# 0.36431573922311206 spread1.SUM(status.var_amp5)
# 0.3476083545379774 spread1.SUM(status.var_amp6)
# 0.2782195982792975 spread1.SUM(status.var_fre1)
# 0.3386530980793471 spread1.SUM(status.var_fre2)
# 0.2666675565341965 spread1.SUM(status.var_fre3)
# 0.2886983466906385 spread1.SUM(status.var_fre4)
# 0.2666460942115801 spread1.SUM(status.var_fre5)
# 0.05816989697820426 spread2.COUNT(status)
# 0.34523180521860813 spread2.MAX(status.D2)
# 0.23368761250061723 spread2.MAX(status.DFA)
# 0.190443656767598 spread2.MAX(status.NHR)
# 0.5367621695764183 spread2.MAX(status.PPE)
# 0.31465245147148635 spread2.MAX(status.RPDE)
# 0.3721853634890291 spread2.MAX(status.var_amp1)
# 0.3547190757452646 spread2.MAX(status.var_amp2)
# 0.35243087173023113 spread2.MAX(status.var_amp3)
# 0.3554952019717419 spread2.MAX(status.var_amp4)
# 0.369018381911037 spread2.MAX(status.var_amp5)
# 0.3524244365488079 spread2.MAX(status.var_amp6)
# 0.27989121448262 spread2.MAX(status.var_fre1)
# 0.33977112376264845 spread2.MAX(status.var_fre2)
# 0.2679745807419859 spread2.MAX(status.var_fre3)
# 0.2903822102008197 spread2.MAX(status.var_fre4)
# 0.26794870332231135 spread2.MAX(status.var_fre5)
# 0.34115062194828927 spread2.MEAN(status.D2)
# 0.23184606905678323 spread2.MEAN(status.DFA)
# 0.18945312161663644 spread2.MEAN(status.NHR)
# 0.5327146094371995 spread2.MEAN(status.PPE)
# 0.30965902725729305 spread2.MEAN(status.RPDE)
# 0.3685131826224942 spread2.MEAN(status.var_amp1)
# 0.35137292018895316 spread2.MEAN(status.var_amp2)
# 0.34863466260414416 spread2.MEAN(status.var_amp3)
# 0.3520057910102832 spread2.MEAN(status.var_amp4)
# 0.36552494914093625 spread2.MEAN(status.var_amp5)
# 0.3486269439590079 spread2.MEAN(status.var_amp6)
# 0.2782927856916354 spread2.MEAN(status.var_fre1)
# 0.33868909434334343 spread2.MEAN(status.var_fre2)
# 0.2667105824757741 spread2.MEAN(status.var_fre3)
# 0.2887735262043391 spread2.MEAN(status.var_fre4)
# 0.26668884369693924 spread2.MEAN(status.var_fre5)
# 0.3352730624949839 spread2.MIN(status.D2)
# 0.22979645450350342 spread2.MIN(status.DFA)
# 0.18841654779966782 spread2.MIN(status.NHR)
# 0.5253763754753134 spread2.MIN(status.PPE)
# 0.30255569800510185 spread2.MIN(status.RPDE)
# 0.3627046345245243 spread2.MIN(status.var_amp1)
# 0.3466987226838437 spread2.MIN(status.var_amp2)
# 0.34283473034205564 spread2.MIN(status.var_amp3)
# 0.3468267891247719 spread2.MIN(status.var_amp4)
# 0.35963744378726625 spread2.MIN(status.var_amp5)
# 0.34282397260952713 spread2.MIN(status.var_amp6)
# 0.2765539977780684 spread2.MIN(status.var_fre1)
# 0.3375378305669023 spread2.MIN(status.var_fre2)
# 0.26536428025853265 spread2.MIN(status.var_fre3)
# 0.28702067000297765 spread2.MIN(status.var_fre4)
# 0.26534720591324024 spread2.MIN(status.var_fre5)
# 0.32668501993021876 spread2.SUM(status.D2)
# 0.1908337765197186 spread2.SUM(status.DFA)
# 0.1913098686436275 spread2.SUM(status.NHR)
# 0.5363120629201766 spread2.SUM(status.PPE)
# 0.31224755454386005 spread2.SUM(status.RPDE)
# 0.37365785570896765 spread2.SUM(status.var_amp1)
# 0.3567792097765262 spread2.SUM(status.var_amp2)
# 0.35406135643462794 spread2.SUM(status.var_amp3)
# 0.3572518034730906 spread2.SUM(status.var_amp4)
# 0.3700632208853045 spread2.SUM(status.var_amp5)
# 0.3540537626278027 spread2.SUM(status.var_amp6)
# 0.2830738096813398 spread2.SUM(status.var_fre1)
# 0.343389296151804 spread2.SUM(status.var_fre2)
# 0.2704678198957947 spread2.SUM(status.var_fre3)
# 0.2933515159894374 spread2.SUM(status.var_fre4)
# 0.27044854888122155 spread2.SUM(status.var_fre5)
# 0.23173927276037898 D2.MAX(status.DFA)
# 0.18942931888728265 D2.MAX(status.NHR)
# 0.5310391538731206 D2.MAX(status.PPE)
# 0.30856725130270324 D2.MAX(status.RPDE)
# 0.4548421261086427 D2.MAX(status.spread2)
# 0.3674298598935416 D2.MAX(status.var_amp1)
# 0.3506969057174749 D2.MAX(status.var_amp2)
# 0.34761696522403307 D2.MAX(status.var_amp3)
# 0.3511484359380265 D2.MAX(status.var_amp4)
# 0.36431573922311206 D2.MAX(status.var_amp5)
# 0.3476083545379774 D2.MAX(status.var_amp6)
# 0.2782195982792975 D2.MAX(status.var_fre1)
# 0.3386530980793471 D2.MAX(status.var_fre2)
# 0.2666675565341965 D2.MAX(status.var_fre3)
# 0.2886983466906385 D2.MAX(status.var_fre4)
# 0.2666460942115801 D2.MAX(status.var_fre5)
# 0.23173927276037898 D2.MEAN(status.DFA)
# 0.18942931888728265 D2.MEAN(status.NHR)
# 0.5310391538731206 D2.MEAN(status.PPE)
# 0.30856725130270324 D2.MEAN(status.RPDE)
# 0.4548421261086427 D2.MEAN(status.spread2)
# 0.3674298598935416 D2.MEAN(status.var_amp1)
# 0.3506969057174749 D2.MEAN(status.var_amp2)
# 0.34761696522403307 D2.MEAN(status.var_amp3)
# 0.3511484359380265 D2.MEAN(status.var_amp4)
# 0.36431573922311206 D2.MEAN(status.var_amp5)
# 0.3476083545379774 D2.MEAN(status.var_amp6)
# 0.2782195982792975 D2.MEAN(status.var_fre1)
# 0.3386530980793471 D2.MEAN(status.var_fre2)
# 0.2666675565341965 D2.MEAN(status.var_fre3)
# 0.2886983466906385 D2.MEAN(status.var_fre4)
# 0.2666460942115801 D2.MEAN(status.var_fre5)
# 0.23173927276037898 D2.MIN(status.DFA)
# 0.18942931888728265 D2.MIN(status.NHR)
# 0.5310391538731206 D2.MIN(status.PPE)
# 0.30856725130270324 D2.MIN(status.RPDE)
# 0.4548421261086427 D2.MIN(status.spread2)
# 0.3674298598935416 D2.MIN(status.var_amp1)
# 0.3506969057174749 D2.MIN(status.var_amp2)
# 0.34761696522403307 D2.MIN(status.var_amp3)
# 0.3511484359380265 D2.MIN(status.var_amp4)
# 0.36431573922311206 D2.MIN(status.var_amp5)
# 0.3476083545379774 D2.MIN(status.var_amp6)
# 0.2782195982792975 D2.MIN(status.var_fre1)
# 0.3386530980793471 D2.MIN(status.var_fre2)
# 0.2666675565341965 D2.MIN(status.var_fre3)
# 0.2886983466906385 D2.MIN(status.var_fre4)
# 0.2666460942115801 D2.MIN(status.var_fre5)
# 0.23173927276037898 D2.SUM(status.DFA)
# 0.18942931888728265 D2.SUM(status.NHR)
# 0.5310391538731206 D2.SUM(status.PPE)
# 0.30856725130270324 D2.SUM(status.RPDE)
# 0.4548421261086427 D2.SUM(status.spread2)
# 0.3674298598935416 D2.SUM(status.var_amp1)
# 0.3506969057174749 D2.SUM(status.var_amp2)
# 0.34761696522403307 D2.SUM(status.var_amp3)
# 0.3511484359380265 D2.SUM(status.var_amp4)
# 0.36431573922311206 D2.SUM(status.var_amp5)
# 0.3476083545379774 D2.SUM(status.var_amp6)
# 0.2782195982792975 D2.SUM(status.var_fre1)
# 0.3386530980793471 D2.SUM(status.var_fre2)
# 0.2666675565341965 D2.SUM(status.var_fre3)
# 0.2886983466906385 D2.SUM(status.var_fre4)
# 0.2666460942115801 D2.SUM(status.var_fre5)
# 0.34023150988036344 PPE.MAX(status.D2)
# 0.23173927276037898 PPE.MAX(status.DFA)
# 0.18942931888728265 PPE.MAX(status.NHR)
# 0.30856725130270324 PPE.MAX(status.RPDE)
# 0.4548421261086427 PPE.MAX(status.spread2)
# 0.3674298598935416 PPE.MAX(status.var_amp1)
# 0.3506969057174749 PPE.MAX(status.var_amp2)
# 0.34761696522403307 PPE.MAX(status.var_amp3)
# 0.3511484359380265 PPE.MAX(status.var_amp4)
# 0.36431573922311206 PPE.MAX(status.var_amp5)
# 0.3476083545379774 PPE.MAX(status.var_amp6)
# 0.2782195982792975 PPE.MAX(status.var_fre1)
# 0.3386530980793471 PPE.MAX(status.var_fre2)
# 0.2666675565341965 PPE.MAX(status.var_fre3)
# 0.2886983466906385 PPE.MAX(status.var_fre4)
# 0.2666460942115801 PPE.MAX(status.var_fre5)
# 0.34023150988036344 PPE.MEAN(status.D2)
# 0.23173927276037898 PPE.MEAN(status.DFA)
# 0.18942931888728265 PPE.MEAN(status.NHR)
# 0.30856725130270324 PPE.MEAN(status.RPDE)
# 0.4548421261086427 PPE.MEAN(status.spread2)
# 0.3674298598935416 PPE.MEAN(status.var_amp1)
# 0.3506969057174749 PPE.MEAN(status.var_amp2)
# 0.34761696522403307 PPE.MEAN(status.var_amp3)
# 0.3511484359380265 PPE.MEAN(status.var_amp4)
# 0.36431573922311206 PPE.MEAN(status.var_amp5)
# 0.3476083545379774 PPE.MEAN(status.var_amp6)
# 0.2782195982792975 PPE.MEAN(status.var_fre1)
# 0.3386530980793471 PPE.MEAN(status.var_fre2)
# 0.2666675565341965 PPE.MEAN(status.var_fre3)
# 0.2886983466906385 PPE.MEAN(status.var_fre4)
# 0.2666460942115801 PPE.MEAN(status.var_fre5)
# 0.34023150988036344 PPE.MIN(status.D2)
# 0.23173927276037898 PPE.MIN(status.DFA)
# 0.18942931888728265 PPE.MIN(status.NHR)
# 0.30856725130270324 PPE.MIN(status.RPDE)
# 0.4548421261086427 PPE.MIN(status.spread2)
# 0.3674298598935416 PPE.MIN(status.var_amp1)
# 0.3506969057174749 PPE.MIN(status.var_amp2)
# 0.34761696522403307 PPE.MIN(status.var_amp3)
# 0.3511484359380265 PPE.MIN(status.var_amp4)
# 0.36431573922311206 PPE.MIN(status.var_amp5)
# 0.3476083545379774 PPE.MIN(status.var_amp6)
# 0.2782195982792975 PPE.MIN(status.var_fre1)
# 0.3386530980793471 PPE.MIN(status.var_fre2)
# 0.2666675565341965 PPE.MIN(status.var_fre3)
# 0.2886983466906385 PPE.MIN(status.var_fre4)
# 0.2666460942115801 PPE.MIN(status.var_fre5)
# 0.34023150988036344 PPE.SUM(status.D2)
# 0.23173927276037898 PPE.SUM(status.DFA)
# 0.18942931888728265 PPE.SUM(status.NHR)
# 0.30856725130270324 PPE.SUM(status.RPDE)
# 0.4548421261086427 PPE.SUM(status.spread2)
# 0.3674298598935416 PPE.SUM(status.var_amp1)
# 0.3506969057174749 PPE.SUM(status.var_amp2)
# 0.34761696522403307 PPE.SUM(status.var_amp3)
# 0.3511484359380265 PPE.SUM(status.var_amp4)
# 0.36431573922311206 PPE.SUM(status.var_amp5)
# 0.3476083545379774 PPE.SUM(status.var_amp6)
# 0.2782195982792975 PPE.SUM(status.var_fre1)
# 0.3386530980793471 PPE.SUM(status.var_fre2)
# 0.2666675565341965 PPE.SUM(status.var_fre3)
# 0.2886983466906385 PPE.SUM(status.var_fre4)
# 0.2666460942115801 PPE.SUM(status.var_fre5)
# 0.9999999999999998 status
# ['var_amp1.MAX(status.RPDE)',
#  'var_amp3.SUM(status.DFA)',
#  'var_fre2.MAX(status.var_amp2)',
#  'var_amp3.SUM(status.D2)',
#  'var_fre2.SKEW(status.var_fre5)',
#  'var_fre5.MEAN(status.spread2)',
#  'var_fre3.MAX(status.var_amp3)',
#  'var_amp2.MIN(status.DFA)',
#  'var_fre1.MAX(status.spread2)',
#  'spread2.SUM(status.D2)',
#  'var_amp2.SUM(status.NHR)',
#  'var_fre2.MAX(status.var_amp1)',
#  'var_amp2.SUM(status.var_fre1)',
#  'var_amp6.SUM(status.D2)',
#  'var_fre2.SKEW(status.max_fre)',
#  'var_fre2.STD(status.var_amp4)',
#  'status']

# %%
feature_matrix[feats]
# Out:
#      var_amp1.MAX(status.RPDE)  var_amp3.SUM(status.DFA)  \
# id
# 0                         0.61                      0.99
# 1                         0.67                      0.99
# 2                         0.63                      1.00
# 3                         0.63                      0.99
# 4                         0.61                      1.00
# ..                         ...                       ...
# 190                       0.65                      0.80
# 191                       0.63                      0.83
# 192                       0.59                      0.79
# 193                       0.66                      0.78
# 194                       0.68                      0.81
#
#      var_fre2.MAX(status.var_amp2)  var_amp3.SUM(status.D2)  \
# id
# 0                             0.37                     0.63
# 1                             0.64                     0.68
# 2                             0.63                     0.64
# 3                             0.63                     0.66
# 4                             0.45                     0.64
# ..                             ...                      ...
# 190                           0.59                     0.72
# 191                           0.59                     0.76
# 192                           0.64                     0.73
# 193                           0.49                     0.58
# 194                           0.59                     0.70
#
#      var_fre2.SKEW(status.var_fre5)  var_fre5.MEAN(status.spread2)  \
# id
# 0                              0.95                           0.53
# 1                              0.68                           0.74
# 2                              0.76                           0.69
# 3                              0.76                           0.74
# 4                              0.63                           0.52
# ..                              ...                            ...
# 190                            1.09                           0.27
# 191                            1.09                           0.42
# 192                            0.68                           0.35
# 193                            0.47                           0.53
# 194                            1.09                           0.42
#
#      var_fre3.MAX(status.var_amp3)  var_amp2.MIN(status.DFA)  \
# id
# 0                             0.39                      0.99
# 1                             0.55                      0.99
# 2                             0.49                      1.00
# 3                             0.52                      0.85
# 4                             0.62                      0.78
# ..                             ...                       ...
# 190                           0.41                      0.80
# 191                           0.32                      0.83
# 192                           0.22                      0.79
# 193                           0.39                      0.78
# 194                           0.18                      0.81
#
#      var_fre1.MAX(status.spread2)  spread2.SUM(status.D2)  \
# id
# 0                            0.59                    0.63
# 1                            0.74                    0.68
# 2                            0.69                    0.64
# 3                            0.74                    0.66
# 4                            0.52                    0.64
# ..                            ...                     ...
# 190                          0.27                    0.72
# 191                          0.29                    0.76
# 192                          0.35                    0.73
# 193                          0.46                    0.58
# 194                          0.42                    0.70
#
#      var_amp2.SUM(status.NHR)  var_fre2.MAX(status.var_amp1)  \
# id
# 0                        0.07                           0.42
# 1                        0.06                           0.60
# 2                        0.04                           0.68
# 3                        0.13                           0.68
# 4                        0.43                           0.54
# ..                        ...                            ...
# 190                      0.09                           0.67
# 191                      0.09                           0.67
# 192                      0.34                           0.60
# 193                      0.36                           0.56
# 194                      0.14                           0.67
#
#      var_amp2.SUM(status.var_fre1)  var_amp6.SUM(status.D2)  \
# id
# 0                             0.24                     0.63
# 1                             0.29                     0.68
# 2                             0.32                     0.64
# 3                             0.44                     0.66
# 4                             0.85                     0.64
# ..                             ...                      ...
# 190                           0.14                     0.72
# 191                           0.35                     0.76
# 192                           0.41                     0.73
# 193                           0.43                     0.58
# 194                           0.17                     0.70
#
#      var_fre2.SKEW(status.max_fre)  var_fre2.STD(status.var_amp4)  status
# id
# 0                             0.19                           0.07       1
# 1                             2.29                           0.16       1
# 2                             0.79                           0.18       1
# 3                             0.79                           0.18       1
# 4                             2.00                           0.20       1
# ..                             ...                            ...     ...
# 190                           1.96                           0.13       0
# 191                           1.96                           0.13       0
# 192                           2.29                           0.16       0
# 193                           2.45                           0.13       0
# 194                           1.96                           0.13       0
#
# [195 rows x 17 columns]

# %% [markdown]
# # Splitting and Preprocessing dataset

# %%
feature_matrix = feature_matrix[feats]
train_set = feature_matrix.iloc[:135,:]
test_set  = feature_matrix.iloc[135:,:]

# %%
x_train = train_set.drop('status',1)
x_test = test_set.drop('status',1)
y_train = train_set['status']
y_test = test_set['status']

# %%
for i in x_train.columns:
    print(i)
# Out:
# var_amp1.MAX(status.RPDE)
# var_amp3.SUM(status.DFA)
# var_fre2.MAX(status.var_amp2)
# var_amp3.SUM(status.D2)
# var_fre2.SKEW(status.var_fre5)
# var_fre5.MEAN(status.spread2)
# var_fre3.MAX(status.var_amp3)
# var_amp2.MIN(status.DFA)
# var_fre1.MAX(status.spread2)
# spread2.SUM(status.D2)
# var_amp2.SUM(status.NHR)
# var_fre2.MAX(status.var_amp1)
# var_amp2.SUM(status.var_fre1)
# var_amp6.SUM(status.D2)
# var_fre2.SKEW(status.max_fre)
# var_fre2.STD(status.var_amp4)

# %%
def model_performance(model,x_train = x_train,x_test = x_test,y_train = y_train,y_test = y_test):
    print(f"{model} Performance:\n")
    y_train_pred = cross_val_predict(model,x_train,y_train,cv=4)
    plt.figure(figsize = (10,10))
    sb.heatmap(confusion_matrix(y_train,y_train_pred),annot = True)
    plt.title('Confusion Matrix')
    plt.show()
    print('Precision Score:',precision_score(y_train,y_train_pred))
    print("Recall Score:",recall_score(y_train,y_train_pred))
    print("Accuracy Score:",accuracy_score(y_train,y_train_pred))
    print("Cross Val Score Insample",cross_val_score(model,x_train,y_train,cv=4,scoring='accuracy').mean())
    print("Cross Val Score Outsample",cross_val_score(model,x_test,y_test,cv=4,scoring='accuracy').mean())

# %% [markdown]
# <h2> 1. Logistic Regression</h2>

# %%
model1 = LogisticRegression()
model1.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
model_performance(model1)
# Out:
# LogisticRegression() Performance:
# Precision Score: 0.9304347826086956
# Recall Score: 0.963963963963964
# Accuracy Score: 0.9111111111111111
# Cross Val Score Insample 0.9115418894830659
# Cross Val Score Outsample 0.7333333333333333

# %% [markdown]
# <h2>2.KNN

# %%
model2 = KNeighborsClassifier(n_neighbors = 6)
model2.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=6)

# %%
model_performance(model2)
# Out:
# KNeighborsClassifier(n_neighbors=6) Performance:
# Precision Score: 0.926605504587156
# Recall Score: 0.9099099099099099
# Accuracy Score: 0.8666666666666667
# Cross Val Score Insample 0.8667557932263814
# Cross Val Score Outsample 0.7166666666666667

# %% [markdown]
# <h2> 3. Decision Tree Classifier</h2>

# %%
model3 = DecisionTreeClassifier(max_depth = 4,min_samples_split = 2,max_leaf_nodes = 2)
model3.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=2)

# %%
model_performance(model3)
# Out:
# DecisionTreeClassifier(max_depth=4, max_leaf_nodes=2) Performance:
# Precision Score: 0.9469026548672567
# Recall Score: 0.963963963963964
# Accuracy Score: 0.9259259259259259
# Cross Val Score Insample 0.9262477718360071
# Cross Val Score Outsample 0.75

# %% [markdown]
# <h2> 4 RandomForest Classifier

# %%
model4 = RandomForestClassifier(max_depth = 5,n_estimators = 1000,criterion = 'gini')
model4.fit(x_train,y_train)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=1000)

# %%
model_performance(model4)
# Out:
# RandomForestClassifier(max_depth=5, n_estimators=1000) Performance:
# Precision Score: 0.8907563025210085
# Recall Score: 0.954954954954955
# Accuracy Score: 0.8666666666666667
# Cross Val Score Insample 0.8674242424242424
# Cross Val Score Outsample 0.7

# %% [markdown]
# <h2>5. AdaBoost Classifier </h2>

# %%
model5 = AdaBoostClassifier(DecisionTreeClassifier(max_depth = 4,min_samples_split = 2,max_leaf_nodes = 2),n_estimators = 93)
model5.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                          max_leaf_nodes=2),
#                    n_estimators=93)

# %%
model_performance(model5)
# Out:
# AdaBoostClassifier(base_estimator=DecisionTreeClassifier(max_depth=4,
#                                                          max_leaf_nodes=2),
#                    n_estimators=93) Performance:
# Precision Score: 0.8260869565217391
# Recall Score: 0.8558558558558559
# Accuracy Score: 0.7333333333333333
# Cross Val Score Insample 0.733288770053476
# Cross Val Score Outsample 0.7333333333333334

# %% [markdown]
# <h2> 6. AutoViML

# %%
target_ID = target_ID
train = train_set
test = test_set
sample_submission=''
scoring_parameter ="log_loss"
m, feats, trainm, testm = Auto_ViML(train, target_ID, test, sample_submission,
                                    scoring_parameter=scoring_parameter,
                                    hyper_param='HO',feature_reduction=True,
                                     Boosting_Flag='catboost',Binning_Flag=False,
                                    Add_Poly=0, Stacking_Flag=False,                                    
                                    Imbalanced_Flag=True, KMeans_Featurizer = False,
                                    verbose=0)
# Out:
# ##############  D A T A   S E T  A N A L Y S I S  #######################
# Training Set Shape = (135, 17)
#     Training Set Memory Usage = 0.02 MB
# Test Set Shape = (60, 17)
#     Test Set Memory Usage = 0.01 MB
# Single_Label Target: ['status']
#
# ################ Binary_Classification VISUALIZATION Started #####################
# Random shuffling the data set before training
#     Using HyperOpt which is approximately 3X Faster than GridSearchCV but results vary...
#        Class  -> Counts -> Percent
#            0:      24  ->   17.8%
#            1:     111  ->   82.2%
#     Target status is already numeric. No transformation done.
# Alert! Rare Class is not 1 but 0 in this data set
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     16 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# Number of Processors on this device = 1
# CPU available
#     No GPU active on this device
# #############     D A T A    P R E P A R A T I O N   AND C L E A N I N G     #############
# No Missing Values in train data set
#     Test data has no missing values. Continuing...
#     Completed Label Encoding and Filling of Missing Values for Train and Test Data
# Binary_Classification problem: hyperparameters are being optimized for log_loss
# ############# R E M O V I N G   H I G H L Y  C O R R E L A T E D    V A R S #################
# Removing highly correlated variables using SULA method among (16) numeric variables
#     Removing (5) highly correlated variables:
#     ['var_amp3.SUM(status.D2)', 'var_fre5.MEAN(status.spread2)', 'var_fre2.MAX(status.var_amp1)', 'var_amp2.SUM(status.var_fre1)', 'var_fre2.STD(status.var_amp4)']
#     Following (11) vars selected: ['var_amp1.MAX(status.RPDE)', 'var_fre2.SKEW(status.var_fre5)', 'var_fre3.MAX(status.var_amp3)', 'var_amp2.MIN(status.DFA)', 'spread2.SUM(status.D2)', 'var_fre2.SKEW(status.max_fre)', 'var_fre2.MAX(status.var_amp2)', 'var_fre1.MAX(status.spread2)', 'var_amp3.SUM(status.DFA)', 'var_amp6.SUM(status.D2)', 'var_amp2.SUM(status.NHR)']
# Splitting features into float and categorical (integer) variables:
#     (11) float variables ...
#     (0) categorical vars...
# ############## F E A T U R E   S E L E C T I O N    BY   X G B O O S T    ####################
# Current number of predictors = 11
#     Finding Important Features using Boosted Trees algorithm...
#         using 11 variables...
#         using 9 variables...
#         using 7 variables...
#         using 5 variables...
#         using 3 variables...
#         using 1 variables...
# Found 11 important features
#     Performing limited feature engineering for binning, add_poly and KMeans_Featurizer flags  ...
#     Train CV Split completed with TRAIN rows =  121 , CV rows =  14
#     Binning_Flag set to False or there are no float vars in data set to be binned
#     KMeans_Featurizer set to False or there are no float variables in data
# Skipping MinMax scaling since perform_scaling flag is set to False
# ############### CatBoost M O D E L   B U I L D I N G  B E G I N S  ####################
# Rows in Train data set = 121
#   Features in Train data set = 11
#     Rows in held-out data set = 14
# Finding Best Model and Hyper Parameters for CatBoost model...
#     Baseline Accuracy Needed for Model = 82.22%
#     CPU Count = 4 in this device
# Using CatBoost Model, Estimated Training time = 0.01 mins
# ##################  Imbalanced Model Training  ############################
# Imbalanced Training using SMOTE Rare Class Oversampling method...
# Using SMOTE's over-sampling techniques to make the 2 classes balanced...
#     This is not an Imbalanced data set. No need to use SMOTE but continuing...
#     class_weights = [2.75       0.61111111]
#     class_weighted_rows = {0: 60, 1: 99}
# Training model now on resampled train data: (159, 11). This will take time...
# Learning rate set to 0.012477
# 0:	learn: 0.9245283	test: 0.9338843	test1: 0.8571429	best: 0.8571429 (0)	total: 55.6ms	remaining: 2m 46s
# Warning: Overfitting detector is active, thus evaluation metric is calculated on every iteration. 'metric_period' is ignored for evaluation metric.
# 500:	learn: 1.0000000	test: 1.0000000	test1: 0.8571429	best: 0.8571429 (0)	total: 659ms	remaining: 3.29s
# 1000:	learn: 1.0000000	test: 1.0000000	test1: 0.8571429	best: 0.8571429 (0)	total: 1.22s	remaining: 2.44s
# 1500:	learn: 1.0000000	test: 1.0000000	test1: 0.8571429	best: 0.8571429 (0)	total: 1.78s	remaining: 1.78s
# 2000:	learn: 1.0000000	test: 1.0000000	test1: 0.8571429	best: 0.8571429 (0)	total: 2.33s	remaining: 1.17s
# Stopped by overfitting detector  (2000 iterations wait)
#
# bestTest = 0.8571428571
# bestIteration = 0
#
# Shrink model to first 1 iterations.
#     Resampled data Training time taken = 3 seconds
# ########################################################
# Resampled model results on Held out Validation data:
#               precision    recall  f1-score   support
#
#            0       0.85      0.77      0.81        22
#            1       0.95      0.97      0.96        99
#
#     accuracy                           0.93       121
#    macro avg       0.90      0.87      0.88       121
# weighted avg       0.93      0.93      0.93       121
#
# ##################  Completed Imbalanced Training using <catboost.core.CatBoostClassifier object at 0x7f9f4b1eaf10> ################
#     Actual training time (in seconds): 3
# ###########  Single_Label  M O D E L   R E S U L T S #################
# 5-fold Cross Validation logloss = 1.0
# Finding Best Threshold for Highest F1 Score...
#     Using threshold=0.5. However, 0.490 provides better F1=0.92 for rare class...
# ########################################################
# CatBoost Model Prediction Results on Held Out CV Data Set:
#     Regular Accuracy Score = 14.3%
# Balanced Accuracy = 70.83% with Threshold = 0.50
# Confusion Matrix:
# [[ 1  1]
#  [ 1 11]]
#               precision    recall  f1-score   support
#
#            0       0.50      0.50      0.50         2
#            1       0.92      0.92      0.92        12
#
#     accuracy                           0.86        14
#    macro avg       0.71      0.71      0.71        14
# weighted avg       0.86      0.86      0.86        14
#
# Balanced Accuracy = 50.00% with Threshold = 0.49
# Confusion Matrix:
# [[ 2  0]
#  [12  0]]
#               precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25         2
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.14        14
#    macro avg       0.07      0.50      0.12        14
# weighted avg       0.02      0.14      0.04        14
#
# #####################################################################
# Regular threshold = 0.50 is better
# ################# E N S E M B L E  M O D E L  ##################
# Time taken = 1 seconds
# Based on trying multiple models, Best type of algorithm for this data set is Logistic_Regression_CV
# #############################################################################
#     Displaying results of weighted average ensemble of 5 classifiers
# After multiple models, Ensemble Model Results:
# Binary Class Model Metrics Report
# #####################################################
#     Accuracy          = 14.3%
#     Balanced Accuracy = 50.0%
#     Precision         = 0.0%
#     Average Precision = 7.1%
#     Recall            = 0.0%
#     F1 Score          = 0.0%
# #####################################################
#               precision    recall  f1-score   support
#
#            0       0.14      1.00      0.25         2
#            1       0.00      0.00      0.00        12
#
#     accuracy                           0.14        14
#    macro avg       0.07      0.50      0.12        14
# weighted avg       0.02      0.14      0.04        14
#
# [[ 2  0]
#  [12  0]]
# #############################################################################
# Single Model is better than Ensembling Models for this data set.
#     Time taken for this Target (in seconds) = 11
#     Binning_Flag set to False or there are no float vars in data set to be binned
#     Setting best params for CatBoost model from Initial State since you cannot change params to a fitted Catboost model
#     Number of Categorical and Integer variables used in CatBoost training = 0
# No MinMax scaling performed since scaling flag is set to false
# #####   T R A I N I N G   M O D E L   O N    F U L L   T R A I N  D A T A  #############
# ##################  Imbalanced Model Training  ############################
# Imbalanced Training using SMOTE Rare Class Oversampling method...
# Using SMOTE's over-sampling techniques to make the 2 classes balanced...
#     This is not an Imbalanced data set. No need to use SMOTE but continuing...
#     class_weights = [2.8125     0.60810811]
#     class_weighted_rows = {0: 67, 1: 111}
# Training model now on resampled train data: (178, 11). This will take time...
# Learning rate set to 0.0018
# 0:	learn: 0.9044944	total: 2.57ms	remaining: 7.72s
# 500:	learn: 0.9438202	total: 611ms	remaining: 3.04s
# 1000:	learn: 0.9831461	total: 1.21s	remaining: 2.42s
# 1500:	learn: 0.9943820	total: 1.82s	remaining: 1.82s
# 2000:	learn: 1.0000000	total: 2.43s	remaining: 1.21s
# 2500:	learn: 1.0000000	total: 3.04s	remaining: 607ms
# 2999:	learn: 1.0000000	total: 3.65s	remaining: 0us
#     Resampled data Training time taken = 4 seconds
# ##################  Completed Imbalanced Training using <catboost.core.CatBoostClassifier object at 0x7f9f49997c10> ################
# Learning rate set to 0.0016
# 0:	learn: 0.9259259	total: 1.21ms	remaining: 3.62s
# 500:	learn: 0.9481481	total: 488ms	remaining: 2.43s
# 1000:	learn: 0.9703704	total: 977ms	remaining: 1.95s
# 1500:	learn: 0.9777778	total: 1.47s	remaining: 1.47s
# 2000:	learn: 1.0000000	total: 1.97s	remaining: 982ms
# 2500:	learn: 1.0000000	total: 2.45s	remaining: 489ms
# 2999:	learn: 1.0000000	total: 2.94s	remaining: 0us
#      Actual Training time taken in seconds = 7
# Training of models completed. Now starting predictions on test data...
#     Making test Data predictions using modified Threshold = 0.490
#     Calculating weighted average ensemble of 5 classifiers
#     Plotting Feature Importances to explain the output of model
# ############### P R E D I C T I O N  O N  T E S T   C O M P L E T E D  #################
#     Time taken thus far (in seconds) = 18
# Writing Output files to disk...
#     Saving predictions to ./status/status_Binary_Classification_test_modified.csv
#     Saving predictions to ./status/status_Binary_Classification_submission.csv
#     Saving predictions to ./status/status_Binary_Classification_train_modified.csv
# ###############  C O M P L E T E D  ################
# Time Taken in mins = 0.3 for the Entire Process

# %%
y_train = train['status']
y_test = test['status']
y_train_pred = m.predict(train)
plt.figure(figsize = (10,10))
sb.heatmap(confusion_matrix(y_train,y_train_pred),annot = True)
plt.title('Confusion Matrix')
plt.show()
print('Precision Score:',precision_score(y_train,y_train_pred,average = 'binary'))
print("Recall Score:",recall_score(y_train,y_train_pred,average = 'binary'))
print("Accuracy Score:",accuracy_score(y_train,y_train_pred))
print("Cross Val Score Insample",cross_val_score(m,train,y_train,cv=2,scoring='accuracy').mean())
print("Cross Val Score Outsample",cross_val_score(m,test,y_test,cv=2,scoring='accuracy').mean())
# Out:
# Precision Score: 1.0
# Recall Score: 1.0
# Accuracy Score: 1.0
# Learning rate set to 0.001186
# 0:	learn: 1.0000000	total: 1.35ms	remaining: 4.06s
# 500:	learn: 1.0000000	total: 363ms	remaining: 1.81s
# 1000:	learn: 1.0000000	total: 713ms	remaining: 1.42s
# 1500:	learn: 1.0000000	total: 1.06s	remaining: 1.06s
# 2000:	learn: 1.0000000	total: 1.43s	remaining: 715ms
# 2500:	learn: 1.0000000	total: 1.79s	remaining: 358ms
# 2999:	learn: 1.0000000	total: 2.15s	remaining: 0us
# Learning rate set to 0.001194
# 0:	learn: 1.0000000	total: 777us	remaining: 2.33s
# 500:	learn: 1.0000000	total: 383ms	remaining: 1.91s
# 1000:	learn: 1.0000000	total: 749ms	remaining: 1.5s
# 1500:	learn: 1.0000000	total: 1.12s	remaining: 1.12s
# 2000:	learn: 1.0000000	total: 1.48s	remaining: 741ms
# 2500:	learn: 1.0000000	total: 1.84s	remaining: 368ms
# 2999:	learn: 1.0000000	total: 2.21s	remaining: 0us
# Cross Val Score Insample 0.9552238805970149
# Learning rate set to 0.000842
# 0:	learn: 1.0000000	total: 608us	remaining: 1.82s
# 500:	learn: 1.0000000	total: 264ms	remaining: 1.32s
# 1000:	learn: 1.0000000	total: 520ms	remaining: 1.04s
# 1500:	learn: 1.0000000	total: 777ms	remaining: 776ms
# 2000:	learn: 1.0000000	total: 1.04s	remaining: 520ms
# 2500:	learn: 1.0000000	total: 1.29s	remaining: 258ms
# 2999:	learn: 1.0000000	total: 1.54s	remaining: 0us
# Learning rate set to 0.000842
# 0:	learn: 0.9333333	total: 1.14ms	remaining: 3.42s
# 500:	learn: 1.0000000	total: 260ms	remaining: 1.3s
# 1000:	learn: 1.0000000	total: 533ms	remaining: 1.06s
# 1500:	learn: 1.0000000	total: 805ms	remaining: 804ms
# 2000:	learn: 1.0000000	total: 1.07s	remaining: 533ms
# 2500:	learn: 1.0000000	total: 1.33s	remaining: 266ms
# 2999:	learn: 1.0000000	total: 1.6s	remaining: 0us
# Cross Val Score Outsample 1.0

# %% [markdown]
# # Saving Models

# %%
with open('model_pkl_Parkinsons_AUTOVIML','wb') as files:
    pickle.dump(m,files)

# %%
with open('model_pkl_Parkinsons','wb') as files:
    pickle.dump(model3,files)

# %%
x_train.describe()
# Out:
#        var_amp1.MAX(status.RPDE)  var_amp3.SUM(status.DFA)  \
# count                     135.00                    135.00
# mean                        0.71                      1.00
# std                         0.15                      0.31
# min                         0.37                      0.71
# 25%                         0.62                      0.85
# 50%                         0.71                      0.89
# 75%                         0.84                      0.96
# max                         0.98                      1.97
#
#        var_fre2.MAX(status.var_amp2)  var_amp3.SUM(status.D2)  \
# count                         135.00                   135.00
# mean                            0.41                     0.72
# std                             0.17                     0.22
# min                             0.08                     0.39
# 25%                             0.25                     0.59
# 50%                             0.42                     0.66
# 75%                             0.59                     0.74
# max                             0.71                     1.48
#
#        var_fre2.SKEW(status.var_fre5)  var_fre5.MEAN(status.spread2)  \
# count                          135.00                         135.00
# mean                             0.60                           0.50
# std                              0.51                           0.18
# min                             -0.36                           0.01
# 25%                              0.35                           0.38
# 50%                              0.63                           0.49
# 75%                              1.09                           0.61
# max                              1.23                           0.96
#
#        var_fre3.MAX(status.var_amp3)  var_amp2.MIN(status.DFA)  \
# count                         135.00                    135.00
# mean                            0.30                      0.86
# std                             0.18                      0.06
# min                             0.08                      0.71
# 25%                             0.15                      0.82
# 50%                             0.25                      0.87
# 75%                             0.39                      0.89
# max                             0.98                      1.00
#
#        var_fre1.MAX(status.spread2)  spread2.SUM(status.D2)  \
# count                        135.00                  135.00
# mean                           0.52                    0.65
# std                            0.19                    0.12
# min                            0.01                    0.39
# 25%                            0.40                    0.57
# 50%                            0.52                    0.64
# 75%                            0.62                    0.70
# max                            0.96                    1.24
#
#        var_amp2.SUM(status.NHR)  var_fre2.MAX(status.var_amp1)  \
# count                    135.00                         135.00
# mean                       0.09                           0.47
# std                        0.13                           0.17
# min                        0.00                           0.10
# 25%                        0.03                           0.32
# 50%                        0.06                           0.46
# 75%                        0.09                           0.60
# max                        1.00                           0.79
#
#        var_amp2.SUM(status.var_fre1)  var_amp6.SUM(status.D2)  \
# count                         135.00                   135.00
# mean                            0.27                     0.68
# std                             0.18                     0.17
# min                             0.05                     0.39
# 25%                             0.14                     0.57
# 50%                             0.22                     0.64
# 75%                             0.35                     0.72
# max                             1.00                     1.37
#
#        var_fre2.SKEW(status.max_fre)  var_fre2.STD(status.var_amp4)
# count                         135.00                         135.00
# mean                            1.90                           0.10
# std                             1.48                           0.04
# min                            -0.95                           0.02
# 25%                             1.96                           0.07
# 50%                             2.00                           0.09
# 75%                             2.45                           0.13
# max                             3.77                           0.20
